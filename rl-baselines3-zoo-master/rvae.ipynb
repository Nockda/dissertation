# %%
import tensorflow as tf
import tensorflow_hub as hub
import numpy as np
from matplotlib import pyplot as plt
import cv2
import os
import csv
from tqdm import tqdm

import tensorflow as tf
from tensorflow import shape,math
from tensorflow.keras import Input,layers,Model
from tensorflow.keras.losses import mse,binary_crossentropy
from tensorflow.keras.utils import plot_model

import torch; torch.manual_seed(0)
import torch.nn as nn
import torch.nn.functional as F
import torch.utils
import torch.distributions
device = torch.device('mps:0' if torch.backends.mps.is_available() else 'cpu')

# Check if GPU is available
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %%
import os
import pandas as pd
import numpy as np

output_dir = os.path.join(".", "output_bw")  # Path to the output directory
subdirs = [f.path for f in os.scandir(output_dir) if f.is_dir()]
subdirs.sort()

# Create an empty 3D array to store the combined data
combined_arr = np.empty((len(subdirs),1000, 10))

# Loop through each subdirectory and load the CSV files
for i, subdir in enumerate(subdirs):
    action_filename = os.path.join(subdir, "action.csv")
    obs_filename = os.path.join(subdir, "obs.csv")

    # Load the action and obs CSV files
    action_df = pd.read_csv(action_filename,  header=None)
    obs_df = pd.read_csv(obs_filename,  header=None)

    # Concatenate the DataFrames horizontally
    combined_data = pd.concat([action_df, obs_df], axis=1)

    # Convert combined_data to a 3D array and assign it to combined_arr
    combined_arr[i] = np.reshape(combined_data.values, (1000, 10))

# Print the shape of combined_arr
print(combined_arr.shape)
# Out:
# (10000, 1000, 10)

# %%
# flattened_arr = combined_arr.reshape(10000, 9990)

# %%
# flattened_arr.shape

# %%
# import torch

# combined_df = np.array(combined_arr)
# combined_tensor = torch.from_numpy(combined_df)
# flattened_tensor = combined_tensor.flatten(start_dim=1)

# %%
# # Rename dimensions to 'Seed' and 'Data'
# flattened_tensor.names = ("Seed", "Data")

# # Now flattened_tensor will have dimensions named 'Seed' and 'Data'
# print(flattened_tensor.shape)  # Output: torch.Size([10000, 9990])
# print(flattened_tensor)

# %%
# len(flattened_tensor)

# %%
# import os
# import pandas as pd
# import numpy as np

# output_dir = os.path.join(".", "output_front")  # Path to the output directory
# subdirs = [f.path for f in os.scandir(output_dir) if f.is_dir()]
# subdirs.sort()

# # Create an empty 3D array to store the combined data
# combined_arr = np.empty((len(subdirs), 1000, 2))

# # Loop through each subdirectory and load the CSV files
# for i, subdir in enumerate(subdirs):
#     action_filename = os.path.join(subdir, "action.csv")

#     # Load the action and obs CSV files
#     action_df = pd.read_csv(action_filename,  header=None)

#     # Convert combined_data to a 3D array and assign it to combined_arr
#     combined_arr[i-1] = np.reshape(action_df.values, (1000, 2))

# # Print the shape of combined_arr
# print(combined_arr.shape)

# %%
combined_df = np.array(combined_arr)

# %%
from sklearn.preprocessing import MinMaxScaler
## 정규화하기

# Flatten the combined_arr to 2D
flattened_arr = combined_arr.reshape(-1, combined_arr.shape[-1])

# Create a scaler object
scaler = MinMaxScaler()

# Fit the scaler and transform the data
normalized_arr = scaler.fit_transform(flattened_arr)

# Reshape the normalized data back to the original shape
normalized_arr = normalized_arr.reshape(combined_arr.shape)

# Print the shape of normalized_arr
print(normalized_arr.shape)
# Out:
# (10000, 1000, 10)

# %%
combined_df = np.array(combined_arr)

# %%
## 정규화 다시 되돌리기

# Flatten the normalized_arr to 2D
flattened_normalized_arr = normalized_arr.reshape(-1, normalized_arr.shape[-1])

# Use the inverse_transform method to transform the data back to its original state
original_arr = scaler.inverse_transform(flattened_normalized_arr)

# Reshape the original data back to the original shape
original_arr = original_arr.reshape(combined_arr.shape)

# Print the shape of original_arr
print(original_arr.shape)
# Out:
# (10000, 1000, 10)

# %%
print(np.allclose(original_arr, combined_arr))
# Out:
# True

# %% [markdown]
# # 정규화해서 해보기

# %%
import torch

combined_df = np.array(combined_arr)
combined_tensor = torch.from_numpy(combined_df)
normalized_tensor = torch.from_numpy(normalized_arr)

# %%
import torch
from torch import nn
from torch import optim
from torch.utils.data import DataLoader, TensorDataset
from torch.utils.data.dataset import random_split

class Encoder(nn.Module):
    def __init__(self, input_shape, hidden_dim1, hidden_dim2, hidden_dim3, latent_dim):
        super(Encoder, self).__init__()
        
        self.encoder = nn.Sequential(
            nn.Linear(input_shape, hidden_dim1),
            nn.ReLU(),
            nn.Linear(hidden_dim1, hidden_dim2),
            nn.ReLU(),
            nn.Linear(hidden_dim2, hidden_dim3),
            nn.ReLU(),
            nn.Linear(hidden_dim3, latent_dim * 2)  # mean and variance
        )

    def forward(self, x):
        h = self.encoder(x)
        mu, log_var = h.chunk(2, dim=1)
        return mu, log_var


class Decoder(nn.Module):
    def __init__(self, latent_dim, hidden_dim1, hidden_dim2, hidden_dim3, output_shape):
        super(Decoder, self).__init__()

        self.decoder = nn.Sequential(
            nn.Linear(latent_dim, hidden_dim3),
            nn.ReLU(),
            nn.Linear(hidden_dim3, hidden_dim2),
            nn.ReLU(),
            nn.Linear(hidden_dim2, hidden_dim1),
            nn.ReLU(),
            nn.Linear(hidden_dim1, output_shape),
        )

    def forward(self, z):
        x_reconstructed = self.decoder(z)
        return x_reconstructed


class VAE(nn.Module):
    def __init__(self, input_shape, hidden_dim1, hidden_dim2, hidden_dim3, latent_dim):
        super(VAE, self).__init__()

        self.encoder = Encoder(input_shape, hidden_dim1, hidden_dim2, hidden_dim3, latent_dim)
        self.decoder = Decoder(latent_dim, hidden_dim1, hidden_dim2, hidden_dim3, input_shape)

    def reparameterize(self, mu, log_var):
        std = torch.exp(log_var / 2)
        eps = torch.randn_like(std)
        return mu + eps * std

    def forward(self, x):
        mu, log_var = self.encoder(x)
        z = self.reparameterize(mu, log_var)
        x_reconstructed = self.decoder(z)
        return x_reconstructed, mu, log_var



# Assuming combined_tensor is your data
# Convert the data to float32
dataset = TensorDataset(normalized_tensor.float())

# Define the data loader
batch_size = 256  # adjust as necessary

# Split data into train, validation, and test
train_size = int(0.7 * len(dataset))  # 70% for training
valid_size = int(0.15 * len(dataset))  # 15% for validation
test_size = len(dataset) - train_size - valid_size  # 15% for testing

train_dataset, valid_dataset, test_dataset = random_split(dataset, [train_size, valid_size, test_size])

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
valid_loader = DataLoader(valid_dataset, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=True)

# Hyperparameters
input_shape = combined_tensor.shape[1] * combined_tensor.shape[2]  # modify this to match your data
hidden_dim1 = 24  # modify as needed
hidden_dim2 = 48  # modify as needed
hidden_dim3 = 128  # modify as needed
latent_dim = 2  # modify as needed
lr = 5e-5  # learning rate
n_epochs = 100  # modify as needed
beta = 1
    
# Model, optimizer, and loss function
model = VAE(input_shape, hidden_dim1, hidden_dim2, hidden_dim3, latent_dim)

optimizer = optim.RAdam(model.parameters(), lr=lr)  # Make sure you're using the correct optimizer
loss_fn = nn.MSELoss()  # And the correct loss function


def train(epoch, model, optimizer, loss_fn, train_loader):
    model.train()
    train_loss = 0
    total_recon_loss = 0
    total_kl_div = 0
    for i, batch in enumerate(train_loader):  # using train_loader instead of dataloader
        batch_data = batch[0]  # get the data from the batch
        
        optimizer.zero_grad()

        # Flatten the data
        batch_data = batch_data.view(batch_data.size(0), -1)

        reconstructed_batch, mu, log_var = model(batch_data)

        # Loss: reconstruction loss + KL divergence
        recon_loss = loss_fn(reconstructed_batch, batch_data)
        kl_divergence = -0.5 * torch.sum(1 + log_var - mu.pow(2) - log_var.exp())
        loss = recon_loss + beta*kl_divergence

        loss.backward()
        train_loss += loss.item()
        total_recon_loss += recon_loss.item()
        total_kl_div += kl_divergence.item()
        optimizer.step()

    avg_loss = train_loss / len(train_loader.dataset)
    avg_recon_loss = total_recon_loss / len(train_loader.dataset)
    avg_kl_div = total_kl_div / len(train_loader.dataset)
    print(f'====> Epoch: {epoch} Average loss: {avg_loss}, Recon Loss: {avg_recon_loss}, KL Div: {avg_kl_div}')

    return avg_loss, avg_recon_loss, avg_kl_div

    
import matplotlib.pyplot as plt

# Lists to store losses for each epoch
avg_losses = []
avg_recon_losses = []
avg_kl_divs = []

# Training
for epoch in range(1, n_epochs + 1):
    avg_loss, avg_recon_loss, avg_kl_div = train(epoch, model, optimizer, loss_fn, train_loader)
    avg_losses.append(avg_loss)
    avg_recon_losses.append(avg_recon_loss)
    avg_kl_divs.append(avg_kl_div)

# Plot the losses
plt.figure(figsize=(7,5))
plt.plot(avg_losses, label='Average Loss')
plt.plot(avg_recon_losses, label='Reconstruction Loss')
plt.plot(avg_kl_divs, label='KL Divergence')
plt.title('Losses')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# ====> Epoch: 1 Average loss: 0.0061700812918799265, Recon Loss: 0.001553694133247648, KL Div: 0.004616387162889753
# ====> Epoch: 2 Average loss: 0.00406731630223138, Recon Loss: 0.0015520020638193402, KL Div: 0.0025153142639568874
# ====> Epoch: 3 Average loss: 0.0023811748708997453, Recon Loss: 0.001549322749887194, KL Div: 0.000831852125270026
# ====> Epoch: 4 Average loss: 0.001696217485836574, Recon Loss: 0.0015460416844912937, KL Div: 0.00015017580134528023
# ====> Epoch: 5 Average loss: 0.0015685371330806186, Recon Loss: 0.0015424901459898267, KL Div: 2.6046987090791975e-05
# ====> Epoch: 6 Average loss: 0.0015480633548327855, Recon Loss: 0.0015387595806803022, KL Div: 9.303774152483259e-06
# ====> Epoch: 7 Average loss: 0.0015420304494244712, Recon Loss: 0.0015346804005759102, KL Div: 7.350048848560878e-06
# ====> Epoch: 8 Average loss: 0.001536122999020985, Recon Loss: 0.0015303090683051518, KL Div: 5.8139307158333916e-06
# ====> Epoch: 9 Average loss: 0.0015304096341133117, Recon Loss: 0.001525519860642297, KL Div: 4.88977347101484e-06
# ====> Epoch: 10 Average loss: 0.0015242433420249394, Recon Loss: 0.0015199922280652181, KL Div: 4.251113959721156e-06
# ====> Epoch: 11 Average loss: 0.001517336151429585, Recon Loss: 0.0015135824297155653, KL Div: 3.753721714019775e-06
# ====> Epoch: 12 Average loss: 0.0015091674753597805, Recon Loss: 0.001505803108215332, KL Div: 3.3643671444484164e-06
# ====> Epoch: 13 Average loss: 0.001499191245862416, Recon Loss: 0.0014961195971284595, KL Div: 3.071648733956473e-06
# ====> Epoch: 14 Average loss: 0.0014866596460342406, Recon Loss: 0.0014838191824299949, KL Div: 2.8404636042458673e-06
# ====> Epoch: 15 Average loss: 0.0014714349891458238, Recon Loss: 0.0014688079399721964, KL Div: 2.627049173627581e-06
# ====> Epoch: 16 Average loss: 0.0014530293090002878, Recon Loss: 0.001450601143496377, KL Div: 2.4281655039106098e-06
# ====> Epoch: 17 Average loss: 0.001430752260344369, Recon Loss: 0.001428497450692313, KL Div: 2.254809652056013e-06
# ====> Epoch: 18 Average loss: 0.0014047875659806389, Recon Loss: 0.0014026832112244197, KL Div: 2.1043547562190464e-06
# ====> Epoch: 19 Average loss: 0.0013746972467218127, Recon Loss: 0.001372720101049968, KL Div: 1.9771456718444824e-06
# ====> Epoch: 20 Average loss: 0.0013415204967771259, Recon Loss: 0.0013396686570984976, KL Div: 1.851839678628104e-06
# ====> Epoch: 21 Average loss: 0.0013048757101808276, Recon Loss: 0.0013031347053391593, KL Div: 1.7410048416682652e-06
# ====> Epoch: 22 Average loss: 0.0012657528349331447, Recon Loss: 0.0012641035446098873, KL Div: 1.6492903232574463e-06
# ====> Epoch: 23 Average loss: 0.0012253692618438175, Recon Loss: 0.0012238046314035143, KL Div: 1.5646304403032576e-06
# ====> Epoch: 24 Average loss: 0.001183062242610114, Recon Loss: 0.0011815849840641022, KL Div: 1.4772585460117886e-06
# ====> Epoch: 25 Average loss: 0.0011406717768737249, Recon Loss: 0.0011392709016799928, KL Div: 1.4008751937321254e-06
# ====> Epoch: 26 Average loss: 0.0010982015430927277, Recon Loss: 0.001096862976040159, KL Div: 1.3385670525687082e-06
# ====> Epoch: 27 Average loss: 0.0010559151002338953, Recon Loss: 0.0010546395352908544, KL Div: 1.2755649430411202e-06
# ====> Epoch: 28 Average loss: 0.0010138931359563554, Recon Loss: 0.0010126880088022778, KL Div: 1.2051292828151157e-06
# ====> Epoch: 29 Average loss: 0.0009734762758016587, Recon Loss: 0.0009723226321595056, KL Div: 1.1536436421530588e-06
# ====> Epoch: 30 Average loss: 0.0009346566413130079, Recon Loss: 0.0009335530911173139, KL Div: 1.1035501956939698e-06
# ====> Epoch: 31 Average loss: 0.0008957946726254055, Recon Loss: 0.0008947364858218602, KL Div: 1.0581868035452707e-06
# ====> Epoch: 32 Average loss: 0.0008600493052176067, Recon Loss: 0.0008590272984334401, KL Div: 1.0220067841666086e-06
# ====> Epoch: 33 Average loss: 0.0008236354759761265, Recon Loss: 0.0008226530126162938, KL Div: 9.824633598327637e-07
# ====> Epoch: 34 Average loss: 0.0007900500084672656, Recon Loss: 0.0007891042275088174, KL Div: 9.457809584481376e-07
# ====> Epoch: 35 Average loss: 0.0007572072446346283, Recon Loss: 0.0007562977629048484, KL Div: 9.094817297799247e-07
# ====> Epoch: 36 Average loss: 0.000728023179939815, Recon Loss: 0.0007271335848740169, KL Div: 8.895950657980783e-07
# ====> Epoch: 37 Average loss: 0.0006982525736093521, Recon Loss: 0.0006974000483751297, KL Div: 8.525252342224122e-07
# ====> Epoch: 38 Average loss: 0.0006703916255916867, Recon Loss: 0.0006695736455065864, KL Div: 8.179800851004465e-07
# ====> Epoch: 39 Average loss: 0.0006453114471265248, Recon Loss: 0.000644524342247418, KL Div: 7.871048791067941e-07
# ====> Epoch: 40 Average loss: 0.0006203047292573111, Recon Loss: 0.0006195442761693682, KL Div: 7.604530879429408e-07
# ====> Epoch: 41 Average loss: 0.0005989512034824916, Recon Loss: 0.0005982036973748888, KL Div: 7.475061076028006e-07
# ====> Epoch: 42 Average loss: 0.000578171221273286, Recon Loss: 0.0005774602230106082, KL Div: 7.109982626778739e-07
# ====> Epoch: 43 Average loss: 0.0005588099360466003, Recon Loss: 0.0005581339384828295, KL Div: 6.759975637708392e-07
# ====> Epoch: 44 Average loss: 0.000540367175425802, Recon Loss: 0.0005397234324898038, KL Div: 6.437429359980992e-07
# ====> Epoch: 45 Average loss: 0.0005254749187401363, Recon Loss: 0.0005248539873531886, KL Div: 6.209313869476319e-07
# ====> Epoch: 46 Average loss: 0.0005110559378351484, Recon Loss: 0.0005104557148047856, KL Div: 6.002230303628105e-07
# ====> Epoch: 47 Average loss: 0.0004956261802996907, Recon Loss: 0.0004950423400316919, KL Div: 5.838402679988316e-07
# ====> Epoch: 48 Average loss: 0.0004826973953417369, Recon Loss: 0.0004821342293705259, KL Div: 5.631659712110247e-07
# ====> Epoch: 49 Average loss: 0.00047178266091006145, Recon Loss: 0.00047122925732816966, KL Div: 5.534035818917411e-07
# ====> Epoch: 50 Average loss: 0.0004611440002918243, Recon Loss: 0.00046061024495533534, KL Div: 5.337553364889962e-07
# ====> Epoch: 51 Average loss: 0.0004507054771695818, Recon Loss: 0.0004501875426088061, KL Div: 5.179345607757569e-07
# ====> Epoch: 52 Average loss: 0.0004424615768449647, Recon Loss: 0.0004419588925583022, KL Div: 5.026842866625105e-07
# ====> Epoch: 53 Average loss: 0.0004350726274507386, Recon Loss: 0.0004345836735197476, KL Div: 4.889539309910366e-07
# ====> Epoch: 54 Average loss: 0.0004282198846340179, Recon Loss: 0.00042773998635155816, KL Div: 4.79898282459804e-07
# ====> Epoch: 55 Average loss: 0.0004202401318720409, Recon Loss: 0.0004197745599917003, KL Div: 4.6557188034057617e-07
# ====> Epoch: 56 Average loss: 0.00041483037173748014, Recon Loss: 0.0004143776361431394, KL Div: 4.527355943407331e-07
# ====> Epoch: 57 Average loss: 0.00041041085443326405, Recon Loss: 0.00040995891924415316, KL Div: 4.5193518911089215e-07
# ====> Epoch: 58 Average loss: 0.0004053101007427488, Recon Loss: 0.0004048802661044257, KL Div: 4.298346383231027e-07
# ====> Epoch: 59 Average loss: 0.0004007540377123015, Recon Loss: 0.00040032700023480823, KL Div: 4.2703747749328615e-07
# ====> Epoch: 60 Average loss: 0.0003974282220005989, Recon Loss: 0.00039701387605496814, KL Div: 4.1434594563075474e-07
# ====> Epoch: 61 Average loss: 0.00039331231585570747, Recon Loss: 0.00039290825171130043, KL Div: 4.0406414440699984e-07
# ====> Epoch: 62 Average loss: 0.0003909308995519366, Recon Loss: 0.00039053982070514135, KL Div: 3.9107884679521833e-07
# ====> Epoch: 63 Average loss: 0.0003880407448325838, Recon Loss: 0.00038765314434255875, KL Div: 3.876004900251116e-07
# ====> Epoch: 64 Average loss: 0.0003846251294016838, Recon Loss: 0.00038424977766616006, KL Div: 3.7535173552376883e-07
# ====> Epoch: 65 Average loss: 0.0003821201143520219, Recon Loss: 0.00038175131061247416, KL Div: 3.688037395477295e-07
# ====> Epoch: 66 Average loss: 0.0003822319103138787, Recon Loss: 0.00038187201746872493, KL Div: 3.598928451538086e-07
# ====> Epoch: 67 Average loss: 0.00037876330954687935, Recon Loss: 0.00037841017757143296, KL Div: 3.5313197544642856e-07
# ====> Epoch: 68 Average loss: 0.00037753188290766306, Recon Loss: 0.00037718308504138676, KL Div: 3.487978662763323e-07
# ====> Epoch: 69 Average loss: 0.00037724395522049497, Recon Loss: 0.0003768943484340395, KL Div: 3.496067864554269e-07
# ====> Epoch: 70 Average loss: 0.0003746409277830805, Recon Loss: 0.00037430562185389657, KL Div: 3.3530592918395994e-07
# ====> Epoch: 71 Average loss: 0.0003738940028207643, Recon Loss: 0.0003735639165554728, KL Div: 3.3008626529148645e-07
# ====> Epoch: 72 Average loss: 0.0003732599552188601, Recon Loss: 0.0003729320743254253, KL Div: 3.27880893434797e-07
# ====> Epoch: 73 Average loss: 0.0003713660016655922, Recon Loss: 0.0003710582075374467, KL Div: 3.077941281454904e-07
# ====> Epoch: 74 Average loss: 0.00037072373075144633, Recon Loss: 0.0003704055952174323, KL Div: 3.1813553401402063e-07
# ====> Epoch: 75 Average loss: 0.0003697029852441379, Recon Loss: 0.000369409411081246, KL Div: 2.935741628919329e-07
# ====> Epoch: 76 Average loss: 0.0003700355589389801, Recon Loss: 0.00036973202654293604, KL Div: 3.035323960440499e-07
# ====> Epoch: 77 Average loss: 0.00036786927921431405, Recon Loss: 0.0003675778295312609, KL Div: 2.914496830531529e-07
# ====> Epoch: 78 Average loss: 0.00036991945654153826, Recon Loss: 0.0003696362876466342, KL Div: 2.8316889490400044e-07
# ====> Epoch: 79 Average loss: 0.00036922256861414226, Recon Loss: 0.000368930561201913, KL Div: 2.9200741222926547e-07
# ====> Epoch: 80 Average loss: 0.0003685933809195246, Recon Loss: 0.000368318786578519, KL Div: 2.7459434100559777e-07
# ====> Epoch: 81 Average loss: 0.0003684212757008416, Recon Loss: 0.0003681583723851613, KL Div: 2.629033156803676e-07
# ====> Epoch: 82 Average loss: 0.0003676657463823046, Recon Loss: 0.00036739729983466013, KL Div: 2.6844654764447896e-07
# ====> Epoch: 83 Average loss: 0.00036668564804962704, Recon Loss: 0.00036642196987356457, KL Div: 2.636781760624477e-07
# ====> Epoch: 84 Average loss: 0.00036609039029904776, Recon Loss: 0.00036582516240222114, KL Div: 2.6522789682660785e-07
# ====> Epoch: 85 Average loss: 0.0003668708737407412, Recon Loss: 0.0003666286872965949, KL Div: 2.4218644414629253e-07
# ====> Epoch: 86 Average loss: 0.0003658587293965476, Recon Loss: 0.0003656210133007595, KL Div: 2.3771609578813825e-07
# ====> Epoch: 87 Average loss: 0.0003649268735732351, Recon Loss: 0.0003646838909813336, KL Div: 2.429825919015067e-07
# ====> Epoch: 88 Average loss: 0.00036546651273965835, Recon Loss: 0.0003652115666440555, KL Div: 2.5494609560285295e-07
# ====> Epoch: 89 Average loss: 0.00036482096144131254, Recon Loss: 0.00036457109451293947, KL Div: 2.498669283730643e-07
# ====> Epoch: 90 Average loss: 0.00036473794707230157, Recon Loss: 0.0003645046204328537, KL Div: 2.3332663944789342e-07
# ====> Epoch: 91 Average loss: 0.00036596171664340156, Recon Loss: 0.0003657357809799058, KL Div: 2.2593566349574497e-07
# ====> Epoch: 92 Average loss: 0.000365789138845035, Recon Loss: 0.00036556237297398703, KL Div: 2.2676587104797363e-07
# ====> Epoch: 93 Average loss: 0.00036440806410142354, Recon Loss: 0.00036418123011078155, KL Div: 2.2683399064200266e-07
# ====> Epoch: 94 Average loss: 0.00036418537476233076, Recon Loss: 0.00036396686413458417, KL Div: 2.1851062774658203e-07
# ====> Epoch: 95 Average loss: 0.00036609796221767155, Recon Loss: 0.0003658788470285279, KL Div: 2.1911518914358957e-07
# ====> Epoch: 96 Average loss: 0.000365427203476429, Recon Loss: 0.00036520905047655107, KL Div: 2.181529998779297e-07
# ====> Epoch: 97 Average loss: 0.00036517972499132157, Recon Loss: 0.00036496770275490625, KL Div: 2.1202223641531807e-07
# ====> Epoch: 98 Average loss: 0.00036500563472509383, Recon Loss: 0.0003647800950067384, KL Div: 2.2553971835545132e-07
# ====> Epoch: 99 Average loss: 0.00036414082986967904, Recon Loss: 0.0003639288672379085, KL Div: 2.1196263177054268e-07
# ====> Epoch: 100 Average loss: 0.00036451409012079237, Recon Loss: 0.00036429100270782196, KL Div: 2.2308741297040666e-07

# %%
def compare_data(data):

    # Get the first row from the dataframe
    first_row = data.iloc[0]

    # Reshape it to (1000, 10)
    reshaped_array = np.reshape(first_row.values, (1000, 2))

    # Convert it back to a dataframe
    reshaped_df = pd.DataFrame(reshaped_array)
    recon_combined_tensor = torch.tensor(reshaped_df.values)
    return recon_combined_tensor

# %%
def test_model(model, test_loader):
    model.eval()
    with torch.no_grad():
        for i, batch in enumerate(test_loader):
            batch_data = batch[0]  # get the data from the batch
            batch_data = batch_data.view(batch_data.size(0), -1)  # flatten the data
            reconstructed_batch, _, _ = model(batch_data)  # get reconstructed data from the model

            # Convert tensors to numpy arrays for use in pandas
            original_data = batch_data.detach().cpu().numpy()
            reconstructed_data = reconstructed_batch.detach().cpu().numpy()

            # Convert to dataframes
            original_df = pd.DataFrame(original_data)
            reconstructed_df = pd.DataFrame(reconstructed_data)

            if i == 0:  # for the first iteration, create the dataframes
                all_original_df = original_df
                all_reconstructed_df = reconstructed_df
            else:  # for subsequent iterations, append to the existing dataframes
                all_original_df = pd.concat([all_original_df, original_df])
                all_reconstructed_df = pd.concat([all_reconstructed_df, reconstructed_df])
    
    return all_original_df, all_reconstructed_df

# Call the function after training
original_df, reconstructed_df = test_model(model, test_loader)

# 두 데이터 비교

# Flatten the tensors
oriori = compare_data(original_df)
reconrecon = compare_data(reconstructed_df)

# Calculate the Euclidean distance
euclidean_distance = torch.norm(oriori.flatten() - reconrecon.flatten())


print(euclidean_distance)
# Out:
# tensor(24.1263)

# %%
## 정규화 다시 되돌리기

reconstructed_arr = np.array(reconrecon)

# Flatten the normalized_arr to 2D
flattened_normalized_arr = reconstructed_arr.reshape(-1, normalized_arr.shape[-1])

# Use the inverse_transform method to transform the data back to its original state
original_arr = scaler.inverse_transform(flattened_normalized_arr)

# Reshape the original data back to the original shape
original_arr = original_arr.reshape(reconstructed_arr.shape)

# Print the shape of original_arr
print(original_arr.shape)
original_df = pd.DataFrame(original_arr)

original_df.shape

replay(original_df)
# Out:
# (1000, 2)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 20
#      16 original_df = pd.DataFrame(original_arr)
#      18 original_df.shape
# ---> 20 replay(original_df)
#
# NameError: name 'replay' is not defined

# %%
## 정규화 오리지날 데이터 다시 되돌리기

reconstructed_arr = np.array(oriori)

# Flatten the normalized_arr to 2D
flattened_normalized_arr = reconstructed_arr.reshape(-1, normalized_arr.shape[-1])

# Use the inverse_transform method to transform the data back to its original state
original_arr = scaler.inverse_transform(flattened_normalized_arr)

# Reshape the original data back to the original shape
original_arr = original_arr.reshape(reconstructed_arr.shape)

# Print the shape of original_arr
print(original_arr.shape)
original_df = pd.DataFrame(original_arr)

original_df.shape

replay(original_df)
# Out:
# (1000, 2)
# 0   -0.648839
# 1   -1.000000
# Name: 0, dtype: float32
# Creating window glfw
# 0   -1.0
# 1   -1.0
# Name: 1, dtype: float32
# /opt/homebrew/Caskroom/miniconda/base/envs/firstenv/lib/python3.11/site-packages/gym/envs/registration.py:555: UserWarning: WARN: The environment Swimmer-v3 is out of date. You should consider upgrading to version `v4`.
#   logger.warn(
# /opt/homebrew/Caskroom/miniconda/base/envs/firstenv/lib/python3.11/site-packages/gym/envs/mujoco/mujoco_env.py:190: UserWarning: WARN: This version of the mujoco environments depends on the mujoco-py bindings, which are no longer maintained and may stop working. Please upgrade to the v4 versions of the environments (which depend on the mujoco python bindings instead), unless you are trying to precisely replicate previous works).
#   logger.warn(
# /opt/homebrew/Caskroom/miniconda/base/envs/firstenv/lib/python3.11/site-packages/gym/utils/passive_env_checker.py:233: DeprecationWarning: `np.bool8` is a deprecated alias for `np.bool_`.  (Deprecated NumPy 1.24)
#   if not isinstance(terminated, (bool, np.bool8)):
# 0   -1.0
# 1   -1.0
# Name: 2, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 3, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 4, dtype: float32
# 0   -1.000000
# 1   -0.430789
# Name: 5, dtype: float32
# 0   -1.000000
# 1   -0.069674
# Name: 6, dtype: float32
# 0   -0.482194
# 1    0.733288
# Name: 7, dtype: float32
# 0    0.795897
# 1    0.954825
# Name: 8, dtype: float32
# 0    1.0
# 1    1.0
# Name: 9, dtype: float32
# 0    1.0
# 1    1.0
# Name: 10, dtype: float32
# 0    1.0
# 1    1.0
# Name: 11, dtype: float32
# 0    1.0
# 1    1.0
# Name: 12, dtype: float32
# 0    1.0
# 1    1.0
# Name: 13, dtype: float32
# 0    1.0
# 1    1.0
# Name: 14, dtype: float32
# 0    1.0
# 1    1.0
# Name: 15, dtype: float32
# 0    1.0
# 1    1.0
# Name: 16, dtype: float32
# 0    1.0
# 1    1.0
# Name: 17, dtype: float32
# 0    1.0
# 1    1.0
# Name: 18, dtype: float32
# 0    1.000000
# 1    0.921152
# Name: 19, dtype: float32
# 0    1.000000
# 1    0.804239
# Name: 20, dtype: float32
# 0    1.000000
# 1    0.719324
# Name: 21, dtype: float32
# 0    1.000000
# 1    0.520269
# Name: 22, dtype: float32
# 0    1.000000
# 1    0.054166
# Name: 23, dtype: float32
# 0    0.632799
# 1   -0.183950
# Name: 24, dtype: float32
# 0   -0.204603
# 1   -0.671383
# Name: 25, dtype: float32
# 0   -0.700333
# 1   -1.000000
# Name: 26, dtype: float32
# 0   -0.688746
# 1   -1.000000
# Name: 27, dtype: float32
# 0   -0.776807
# 1   -1.000000
# Name: 28, dtype: float32
# 0   -0.814485
# 1   -1.000000
# Name: 29, dtype: float32
# 0   -0.851719
# 1   -1.000000
# Name: 30, dtype: float32
# 0   -0.941957
# 1   -1.000000
# Name: 31, dtype: float32
# 0   -0.969637
# 1   -1.000000
# Name: 32, dtype: float32
# 0   -0.972979
# 1   -1.000000
# Name: 33, dtype: float32
# 0   -0.981669
# 1   -1.000000
# Name: 34, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 35, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 36, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 37, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 38, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 39, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 40, dtype: float32
# 0   -1.000000
# 1   -0.960976
# Name: 41, dtype: float32
# 0   -1.000000
# 1   -0.764808
# Name: 42, dtype: float32
# 0   -1.000000
# 1   -0.520842
# Name: 43, dtype: float32
# 0   -1.000000
# 1    0.003628
# Name: 44, dtype: float32
# 0   -0.725274
# 1    0.798515
# Name: 45, dtype: float32
# 0    0.521313
# 1    1.000000
# Name: 46, dtype: float32
# 0    0.896725
# 1    1.000000
# Name: 47, dtype: float32
# 0    0.938548
# 1    1.000000
# Name: 48, dtype: float32
# 0    1.0
# 1    1.0
# Name: 49, dtype: float32
# 0    0.945933
# 1    1.000000
# Name: 50, dtype: float32
# 0    0.919865
# 1    1.000000
# Name: 51, dtype: float32
# 0    1.0
# 1    1.0
# Name: 52, dtype: float32
# 0    1.0
# 1    1.0
# Name: 53, dtype: float32
# 0    1.0
# 1    1.0
# Name: 54, dtype: float32
# 0    1.0
# 1    1.0
# Name: 55, dtype: float32
# 0    1.0
# 1    1.0
# Name: 56, dtype: float32
# 0    1.0
# 1    1.0
# Name: 57, dtype: float32
# 0    1.0
# 1    1.0
# Name: 58, dtype: float32
# 0    1.000000
# 1    0.801996
# Name: 59, dtype: float32
# 0    1.00000
# 1    0.67721
# Name: 60, dtype: float32
# 0    1.00000
# 1    0.61094
# Name: 61, dtype: float32
# 0    1.000000
# 1    0.264468
# Name: 62, dtype: float32
# 0    1.000000
# 1   -0.133651
# Name: 63, dtype: float32
# 0    0.089006
# 1   -0.125431
# Name: 64, dtype: float32
# 0   -0.667936
# 1   -1.000000
# Name: 65, dtype: float32
# 0   -0.822945
# 1   -1.000000
# Name: 66, dtype: float32
# 0   -0.844922
# 1   -1.000000
# Name: 67, dtype: float32
# 0   -0.883765
# 1   -1.000000
# Name: 68, dtype: float32
# 0   -0.970628
# 1   -1.000000
# Name: 69, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 70, dtype: float32
# 0   -0.990229
# 1   -1.000000
# Name: 71, dtype: float32
# 0   -0.99327
# 1   -1.00000
# Name: 72, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 73, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 74, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 75, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 76, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 77, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 78, dtype: float32
# 0   -1.000000
# 1   -0.881487
# Name: 79, dtype: float32
# 0   -1.000000
# 1   -0.669986
# Name: 80, dtype: float32
# 0   -1.000000
# 1   -0.267094
# Name: 81, dtype: float32
# 0   -1.000000
# 1    0.332753
# Name: 82, dtype: float32
# 0    0.006575
# 1    1.000000
# Name: 83, dtype: float32
# 0    0.824252
# 1    1.000000
# Name: 84, dtype: float32
# 0    0.951528
# 1    1.000000
# Name: 85, dtype: float32
# 0    0.997633
# 1    1.000000
# Name: 86, dtype: float32
# 0    0.994498
# 1    1.000000
# Name: 87, dtype: float32
# 0    0.913767
# 1    1.000000
# Name: 88, dtype: float32
# 0    1.0
# 1    1.0
# Name: 89, dtype: float32
# 0    1.0
# 1    1.0
# Name: 90, dtype: float32
# 0    1.0
# 1    1.0
# Name: 91, dtype: float32
# 0    1.0
# 1    1.0
# Name: 92, dtype: float32
# 0    1.0
# 1    1.0
# Name: 93, dtype: float32
# 0    1.0
# 1    1.0
# Name: 94, dtype: float32
# 0    1.0
# 1    1.0
# Name: 95, dtype: float32
# 0    1.000000
# 1    0.867677
# Name: 96, dtype: float32
# 0    1.000000
# 1    0.671596
# Name: 97, dtype: float32
# 0    1.000000
# 1    0.642393
# Name: 98, dtype: float32
# 0    1.000000
# 1    0.370809
# Name: 99, dtype: float32
# 0    1.000000
# 1   -0.115257
# Name: 100, dtype: float32
# 0    0.321172
# 1   -0.096237
# Name: 101, dtype: float32
# 0   -0.60492
# 1   -1.00000
# Name: 102, dtype: float32
# 0   -0.892868
# 1   -1.000000
# Name: 103, dtype: float32
# 0   -0.852861
# 1   -1.000000
# Name: 104, dtype: float32
# 0   -0.883271
# 1   -1.000000
# Name: 105, dtype: float32
# 0   -0.968088
# 1   -1.000000
# Name: 106, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 107, dtype: float32
# 0   -0.990845
# 1   -1.000000
# Name: 108, dtype: float32
# 0   -0.993631
# 1   -1.000000
# Name: 109, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 110, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 111, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 112, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 113, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 114, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 115, dtype: float32
# 0   -1.000000
# 1   -0.881888
# Name: 116, dtype: float32
# 0   -1.000000
# 1   -0.658149
# Name: 117, dtype: float32
# 0   -1.000000
# 1   -0.229368
# Name: 118, dtype: float32
# 0   -1.000000
# 1    0.385275
# Name: 119, dtype: float32
# 0    0.113579
# 1    1.000000
# Name: 120, dtype: float32
# 0    0.852559
# 1    1.000000
# Name: 121, dtype: float32
# 0    0.957042
# 1    1.000000
# Name: 122, dtype: float32
# 0    1.0
# 1    1.0
# Name: 123, dtype: float32
# 0    0.991413
# 1    1.000000
# Name: 124, dtype: float32
# 0    0.920408
# 1    1.000000
# Name: 125, dtype: float32
# 0    1.0
# 1    1.0
# Name: 126, dtype: float32
# 0    1.0
# 1    1.0
# Name: 127, dtype: float32
# 0    1.0
# 1    1.0
# Name: 128, dtype: float32
# 0    1.0
# 1    1.0
# Name: 129, dtype: float32
# 0    1.0
# 1    1.0
# Name: 130, dtype: float32
# 0    1.0
# 1    1.0
# Name: 131, dtype: float32
# 0    1.0
# 1    1.0
# Name: 132, dtype: float32
# 0    1.000000
# 1    0.824844
# Name: 133, dtype: float32
# 0    1.000000
# 1    0.666113
# Name: 134, dtype: float32
# 0    1.000000
# 1    0.623622
# Name: 135, dtype: float32
# 0    1.000000
# 1    0.310933
# Name: 136, dtype: float32
# 0    1.000000
# 1   -0.138954
# Name: 137, dtype: float32
# 0    0.185758
# 1   -0.112272
# Name: 138, dtype: float32
# 0   -0.654583
# 1   -1.000000
# Name: 139, dtype: float32
# 0   -0.852536
# 1   -1.000000
# Name: 140, dtype: float32
# 0   -0.849959
# 1   -1.000000
# Name: 141, dtype: float32
# 0   -0.886606
# 1   -1.000000
# Name: 142, dtype: float32
# 0   -0.972699
# 1   -1.000000
# Name: 143, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 144, dtype: float32
# 0   -0.991313
# 1   -1.000000
# Name: 145, dtype: float32
# 0   -0.995618
# 1   -1.000000
# Name: 146, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 147, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 148, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 149, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 150, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 151, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 152, dtype: float32
# 0   -1.000000
# 1   -0.879638
# Name: 153, dtype: float32
# 0   -1.000000
# 1   -0.654238
# Name: 154, dtype: float32
# 0   -1.000000
# 1   -0.216274
# Name: 155, dtype: float32
# 0   -1.000000
# 1    0.398875
# Name: 156, dtype: float32
# 0    0.134513
# 1    1.000000
# Name: 157, dtype: float32
# 0    0.850063
# 1    1.000000
# Name: 158, dtype: float32
# 0    0.953381
# 1    1.000000
# Name: 159, dtype: float32
# 0    1.0
# 1    1.0
# Name: 160, dtype: float32
# 0    0.989182
# 1    1.000000
# Name: 161, dtype: float32
# 0    0.918054
# 1    1.000000
# Name: 162, dtype: float32
# 0    1.0
# 1    1.0
# Name: 163, dtype: float32
# 0    1.0
# 1    1.0
# Name: 164, dtype: float32
# 0    1.0
# 1    1.0
# Name: 165, dtype: float32
# 0    1.0
# 1    1.0
# Name: 166, dtype: float32
# 0    1.0
# 1    1.0
# Name: 167, dtype: float32
# 0    1.0
# 1    1.0
# Name: 168, dtype: float32
# 0    1.0
# 1    1.0
# Name: 169, dtype: float32
# 0    1.000000
# 1    0.824523
# Name: 170, dtype: float32
# 0    1.000000
# 1    0.661314
# Name: 171, dtype: float32
# 0    1.000000
# 1    0.621773
# Name: 172, dtype: float32
# 0    1.000000
# 1    0.311176
# Name: 173, dtype: float32
# 0    1.000000
# 1   -0.143514
# Name: 174, dtype: float32
# 0    0.187962
# 1   -0.113560
# Name: 175, dtype: float32
# 0   -0.658087
# 1   -1.000000
# Name: 176, dtype: float32
# 0   -0.857042
# 1   -1.000000
# Name: 177, dtype: float32
# 0   -0.852103
# 1   -1.000000
# Name: 178, dtype: float32
# 0   -0.889116
# 1   -1.000000
# Name: 179, dtype: float32
# 0   -0.97511
# 1   -1.00000
# Name: 180, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 181, dtype: float32
# 0   -0.992059
# 1   -1.000000
# Name: 182, dtype: float32
# 0   -0.997418
# 1   -1.000000
# Name: 183, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 184, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 185, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 186, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 187, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 188, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 189, dtype: float32
# 0   -1.000000
# 1   -0.877354
# Name: 190, dtype: float32
# 0   -1.000000
# 1   -0.645373
# Name: 191, dtype: float32
# 0   -1.000000
# 1   -0.191316
# Name: 192, dtype: float32
# 0   -1.000000
# 1    0.433119
# Name: 193, dtype: float32
# 0    0.194414
# 1    1.000000
# Name: 194, dtype: float32
# 0    0.860135
# 1    1.000000
# Name: 195, dtype: float32
# 0    0.953701
# 1    1.000000
# Name: 196, dtype: float32
# 0    1.0
# 1    1.0
# Name: 197, dtype: float32
# 0    0.986473
# 1    1.000000
# Name: 198, dtype: float32
# 0    0.919934
# 1    1.000000
# Name: 199, dtype: float32
# 0    1.0
# 1    1.0
# Name: 200, dtype: float32
# 0    1.0
# 1    1.0
# Name: 201, dtype: float32
# 0    1.0
# 1    1.0
# Name: 202, dtype: float32
# 0    1.0
# 1    1.0
# Name: 203, dtype: float32
# 0    1.0
# 1    1.0
# Name: 204, dtype: float32
# 0    1.0
# 1    1.0
# Name: 205, dtype: float32
# 0    1.0
# 1    1.0
# Name: 206, dtype: float32
# 0    1.000000
# 1    0.806249
# Name: 207, dtype: float32
# 0    1.000000
# 1    0.655979
# Name: 208, dtype: float32
# 0    1.000000
# 1    0.611672
# Name: 209, dtype: float32
# 0    1.000000
# 1    0.284139
# Name: 210, dtype: float32
# 0    1.000000
# 1   -0.152337
# Name: 211, dtype: float32
# 0    0.133766
# 1   -0.123179
# Name: 212, dtype: float32
# 0   -0.675317
# 1   -1.000000
# Name: 213, dtype: float32
# 0   -0.847361
# 1   -1.000000
# Name: 214, dtype: float32
# 0   -0.852969
# 1   -1.000000
# Name: 215, dtype: float32
# 0   -0.892616
# 1   -1.000000
# Name: 216, dtype: float32
# 0   -0.978703
# 1   -1.000000
# Name: 217, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 218, dtype: float32
# 0   -0.992809
# 1   -1.000000
# Name: 219, dtype: float32
# 0   -0.999657
# 1   -1.000000
# Name: 220, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 221, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 222, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 223, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 224, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 225, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 226, dtype: float32
# 0   -1.000000
# 1   -0.874518
# Name: 227, dtype: float32
# 0   -1.000000
# 1   -0.637165
# Name: 228, dtype: float32
# 0   -1.000000
# 1   -0.169636
# Name: 229, dtype: float32
# 0   -1.000000
# 1    0.462696
# Name: 230, dtype: float32
# 0    0.241357
# 1    1.000000
# Name: 231, dtype: float32
# 0    0.865604
# 1    1.000000
# Name: 232, dtype: float32
# 0    0.952857
# 1    1.000000
# Name: 233, dtype: float32
# 0    1.0
# 1    1.0
# Name: 234, dtype: float32
# 0    0.983666
# 1    1.000000
# Name: 235, dtype: float32
# 0    0.920357
# 1    1.000000
# Name: 236, dtype: float32
# 0    1.0
# 1    1.0
# Name: 237, dtype: float32
# 0    1.0
# 1    1.0
# Name: 238, dtype: float32
# 0    1.0
# 1    1.0
# Name: 239, dtype: float32
# 0    1.0
# 1    1.0
# Name: 240, dtype: float32
# 0    1.0
# 1    1.0
# Name: 241, dtype: float32
# 0    1.0
# 1    1.0
# Name: 242, dtype: float32
# 0    1.0
# 1    1.0
# Name: 243, dtype: float32
# 0    1.000000
# 1    0.794243
# Name: 244, dtype: float32
# 0    1.000000
# 1    0.650386
# Name: 245, dtype: float32
# 0    1.000000
# 1    0.604128
# Name: 246, dtype: float32
# 0    1.000000
# 1    0.266131
# Name: 247, dtype: float32
# 0    1.000000
# 1   -0.159074
# Name: 248, dtype: float32
# 0    0.099971
# 1   -0.130458
# Name: 249, dtype: float32
# 0   -0.686754
# 1   -1.000000
# Name: 250, dtype: float32
# 0   -0.844131
# 1   -1.000000
# Name: 251, dtype: float32
# 0   -0.854505
# 1   -1.000000
# Name: 252, dtype: float32
# 0   -0.896123
# 1   -1.000000
# Name: 253, dtype: float32
# 0   -0.981952
# 1   -1.000000
# Name: 254, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 255, dtype: float32
# 0   -0.993623
# 1   -1.000000
# Name: 256, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 257, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 258, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 259, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 260, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 261, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 262, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 263, dtype: float32
# 0   -1.000000
# 1   -0.871428
# Name: 264, dtype: float32
# 0   -1.000000
# 1   -0.627314
# Name: 265, dtype: float32
# 0   -1.000000
# 1   -0.145915
# Name: 266, dtype: float32
# 0   -0.998104
# 1    0.497539
# Name: 267, dtype: float32
# 0    0.293554
# 1    1.000000
# Name: 268, dtype: float32
# 0    0.872979
# 1    1.000000
# Name: 269, dtype: float32
# 0    0.953058
# 1    1.000000
# Name: 270, dtype: float32
# 0    1.0
# 1    1.0
# Name: 271, dtype: float32
# 0    0.980636
# 1    1.000000
# Name: 272, dtype: float32
# 0    0.921718
# 1    1.000000
# Name: 273, dtype: float32
# 0    1.0
# 1    1.0
# Name: 274, dtype: float32
# 0    1.0
# 1    1.0
# Name: 275, dtype: float32
# 0    1.0
# 1    1.0
# Name: 276, dtype: float32
# 0    1.0
# 1    1.0
# Name: 277, dtype: float32
# 0    1.0
# 1    1.0
# Name: 278, dtype: float32
# 0    1.0
# 1    1.0
# Name: 279, dtype: float32
# 0    1.0
# 1    1.0
# Name: 280, dtype: float32
# 0    1.000000
# 1    0.778774
# Name: 281, dtype: float32
# 0    1.000000
# 1    0.644343
# Name: 282, dtype: float32
# 0    1.000000
# 1    0.594486
# Name: 283, dtype: float32
# 0    1.000000
# 1    0.241887
# Name: 284, dtype: float32
# 0    1.000000
# 1   -0.165327
# Name: 285, dtype: float32
# 0    0.055921
# 1   -0.140112
# Name: 286, dtype: float32
# 0   -0.699408
# 1   -1.000000
# Name: 287, dtype: float32
# 0   -0.840074
# 1   -1.000000
# Name: 288, dtype: float32
# 0   -0.85612
# 1   -1.00000
# Name: 289, dtype: float32
# 0   -0.900264
# 1   -1.000000
# Name: 290, dtype: float32
# 0   -0.985552
# 1   -1.000000
# Name: 291, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 292, dtype: float32
# 0   -0.994519
# 1   -1.000000
# Name: 293, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 294, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 295, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 296, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 297, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 298, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 299, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 300, dtype: float32
# 0   -1.000000
# 1   -0.867638
# Name: 301, dtype: float32
# 0   -1.000000
# 1   -0.616061
# Name: 302, dtype: float32
# 0   -1.000000
# 1   -0.121393
# Name: 303, dtype: float32
# 0   -0.954437
# 1    0.535573
# Name: 304, dtype: float32
# 0    0.329985
# 1    1.000000
# Name: 305, dtype: float32
# 0    0.874616
# 1    1.000000
# Name: 306, dtype: float32
# 0    0.950655
# 1    1.000000
# Name: 307, dtype: float32
# 0    1.0
# 1    1.0
# Name: 308, dtype: float32
# 0    0.976556
# 1    1.000000
# Name: 309, dtype: float32
# 0    0.921808
# 1    1.000000
# Name: 310, dtype: float32
# 0    1.0
# 1    1.0
# Name: 311, dtype: float32
# 0    1.0
# 1    1.0
# Name: 312, dtype: float32
# 0    1.0
# 1    1.0
# Name: 313, dtype: float32
# 0    1.0
# 1    1.0
# Name: 314, dtype: float32
# 0    1.0
# 1    1.0
# Name: 315, dtype: float32
# 0    1.0
# 1    1.0
# Name: 316, dtype: float32
# 0    1.0
# 1    1.0
# Name: 317, dtype: float32
# 0    1.000000
# 1    0.763651
# Name: 318, dtype: float32
# 0    1.000000
# 1    0.637452
# Name: 319, dtype: float32
# 0    1.00000
# 1    0.58333
# Name: 320, dtype: float32
# 0    1.000000
# 1    0.213767
# Name: 321, dtype: float32
# 0    1.000000
# 1   -0.170036
# Name: 322, dtype: float32
# 0    0.006310
# 1   -0.150006
# Name: 323, dtype: float32
# 0   -0.712478
# 1   -1.000000
# Name: 324, dtype: float32
# 0   -0.838234
# 1   -1.000000
# Name: 325, dtype: float32
# 0   -0.858828
# 1   -1.000000
# Name: 326, dtype: float32
# 0   -0.906222
# 1   -1.000000
# Name: 327, dtype: float32
# 0   -0.990326
# 1   -1.000000
# Name: 328, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 329, dtype: float32
# 0   -0.995803
# 1   -1.000000
# Name: 330, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 331, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 332, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 333, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 334, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 335, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 336, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 337, dtype: float32
# 0   -1.000000
# 1   -0.858956
# Name: 338, dtype: float32
# 0   -1.000000
# 1   -0.596448
# Name: 339, dtype: float32
# 0   -1.000000
# 1   -0.085607
# Name: 340, dtype: float32
# 0   -0.886784
# 1    0.598770
# Name: 341, dtype: float32
# 0    0.387478
# 1    1.000000
# Name: 342, dtype: float32
# 0    0.880917
# 1    1.000000
# Name: 343, dtype: float32
# 0    0.94917
# 1    1.00000
# Name: 344, dtype: float32
# 0    1.0
# 1    1.0
# Name: 345, dtype: float32
# 0    0.96999
# 1    1.00000
# Name: 346, dtype: float32
# 0    0.923807
# 1    1.000000
# Name: 347, dtype: float32
# 0    1.0
# 1    1.0
# Name: 348, dtype: float32
# 0    1.0
# 1    1.0
# Name: 349, dtype: float32
# 0    1.0
# 1    1.0
# Name: 350, dtype: float32
# 0    1.0
# 1    1.0
# Name: 351, dtype: float32
# 0    1.0
# 1    1.0
# Name: 352, dtype: float32
# 0    1.0
# 1    1.0
# Name: 353, dtype: float32
# 0    1.0
# 1    1.0
# Name: 354, dtype: float32
# 0    1.000000
# 1    0.739168
# Name: 355, dtype: float32
# 0    1.000000
# 1    0.629652
# Name: 356, dtype: float32
# 0    1.000000
# 1    0.565385
# Name: 357, dtype: float32
# 0    1.000000
# 1    0.166741
# Name: 358, dtype: float32
# 0    0.967727
# 1   -0.170781
# Name: 359, dtype: float32
# 0   -0.073084
# 1   -0.201768
# Name: 360, dtype: float32
# 0   -0.73682
# 1   -1.00000
# Name: 361, dtype: float32
# 0   -0.838114
# 1   -1.000000
# Name: 362, dtype: float32
# 0   -0.863123
# 1   -1.000000
# Name: 363, dtype: float32
# 0   -0.915784
# 1   -1.000000
# Name: 364, dtype: float32
# 0   -0.996725
# 1   -1.000000
# Name: 365, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 366, dtype: float32
# 0   -0.99677
# 1   -1.00000
# Name: 367, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 368, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 369, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 370, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 371, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 372, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 373, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 374, dtype: float32
# 0   -1.000000
# 1   -0.838528
# Name: 375, dtype: float32
# 0   -1.000000
# 1   -0.554532
# Name: 376, dtype: float32
# 0   -1.000000
# 1   -0.023578
# Name: 377, dtype: float32
# 0   -0.757753
# 1    0.725882
# Name: 378, dtype: float32
# 0    0.494455
# 1    1.000000
# Name: 379, dtype: float32
# 0    0.900375
# 1    1.000000
# Name: 380, dtype: float32
# 0    0.952454
# 1    1.000000
# Name: 381, dtype: float32
# 0    1.0
# 1    1.0
# Name: 382, dtype: float32
# 0    0.957198
# 1    1.000000
# Name: 383, dtype: float32
# 0    0.932903
# 1    1.000000
# Name: 384, dtype: float32
# 0    1.0
# 1    1.0
# Name: 385, dtype: float32
# 0    1.0
# 1    1.0
# Name: 386, dtype: float32
# 0    1.0
# 1    1.0
# Name: 387, dtype: float32
# 0    1.0
# 1    1.0
# Name: 388, dtype: float32
# 0    1.0
# 1    1.0
# Name: 389, dtype: float32
# 0    1.0
# 1    1.0
# Name: 390, dtype: float32
# 0    1.0
# 1    1.0
# Name: 391, dtype: float32
# 0    1.00000
# 1    0.68828
# Name: 392, dtype: float32
# 0    1.000000
# 1    0.620067
# Name: 393, dtype: float32
# 0    1.000000
# 1    0.524448
# Name: 394, dtype: float32
# 0    1.000000
# 1    0.065535
# Name: 395, dtype: float32
# 0    0.833235
# 1   -0.156336
# Name: 396, dtype: float32
# 0   -0.244976
# 1   -0.405157
# Name: 397, dtype: float32
# 0   -0.801032
# 1   -1.000000
# Name: 398, dtype: float32
# 0   -0.84699
# 1   -1.00000
# Name: 399, dtype: float32
# 0   -0.873348
# 1   -1.000000
# Name: 400, dtype: float32
# 0   -0.938464
# 1   -1.000000
# Name: 401, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 402, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 403, dtype: float32
# 0   -0.998439
# 1   -1.000000
# Name: 404, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 405, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 406, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 407, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 408, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 409, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 410, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 411, dtype: float32
# 0   -1.000000
# 1   -0.769926
# Name: 412, dtype: float32
# 0   -1.000000
# 1   -0.417083
# Name: 413, dtype: float32
# 0   -1.000000
# 1    0.127308
# Name: 414, dtype: float32
# 0   -0.400158
# 1    1.000000
# Name: 415, dtype: float32
# 0    0.704941
# 1    1.000000
# Name: 416, dtype: float32
# 0    0.950071
# 1    1.000000
# Name: 417, dtype: float32
# 0    0.977978
# 1    1.000000
# Name: 418, dtype: float32
# 0    1.0
# 1    1.0
# Name: 419, dtype: float32
# 0    0.929176
# 1    1.000000
# Name: 420, dtype: float32
# 0    0.971203
# 1    1.000000
# Name: 421, dtype: float32
# 0    1.0
# 1    1.0
# Name: 422, dtype: float32
# 0    1.0
# 1    1.0
# Name: 423, dtype: float32
# 0    1.0
# 1    1.0
# Name: 424, dtype: float32
# 0    1.0
# 1    1.0
# Name: 425, dtype: float32
# 0    1.0
# 1    1.0
# Name: 426, dtype: float32
# 0    1.0
# 1    1.0
# Name: 427, dtype: float32
# 0    1.000000
# 1    0.884344
# Name: 428, dtype: float32
# 0    1.000000
# 1    0.635956
# Name: 429, dtype: float32
# 0    1.000000
# 1    0.609178
# Name: 430, dtype: float32
# 0    1.000000
# 1    0.383511
# Name: 431, dtype: float32
# 0    1.000000
# 1   -0.145241
# Name: 432, dtype: float32
# 0    0.375116
# 1   -0.117992
# Name: 433, dtype: float32
# 0   -0.623641
# 1   -1.000000
# Name: 434, dtype: float32
# 0   -0.951838
# 1   -1.000000
# Name: 435, dtype: float32
# 0   -0.883489
# 1   -1.000000
# Name: 436, dtype: float32
# 0   -0.911739
# 1   -1.000000
# Name: 437, dtype: float32
# 0   -0.993599
# 1   -1.000000
# Name: 438, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 439, dtype: float32
# 0   -0.999998
# 1   -1.000000
# Name: 440, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 441, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 442, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 443, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 444, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 445, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 446, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 447, dtype: float32
# 0   -1.000000
# 1   -0.843042
# Name: 448, dtype: float32
# 0   -1.00000
# 1   -0.52308
# Name: 449, dtype: float32
# 0   -1.000000
# 1    0.016787
# Name: 450, dtype: float32
# 0   -0.652704
# 1    0.820248
# Name: 451, dtype: float32
# 0    0.58339
# 1    1.00000
# Name: 452, dtype: float32
# 0    0.929882
# 1    1.000000
# Name: 453, dtype: float32
# 0    0.9685
# 1    1.0000
# Name: 454, dtype: float32
# 0    1.0
# 1    1.0
# Name: 455, dtype: float32
# 0    0.951787
# 1    1.000000
# Name: 456, dtype: float32
# 0    0.954959
# 1    1.000000
# Name: 457, dtype: float32
# 0    1.0
# 1    1.0
# Name: 458, dtype: float32
# 0    1.0
# 1    1.0
# Name: 459, dtype: float32
# 0    1.0
# 1    1.0
# Name: 460, dtype: float32
# 0    1.0
# 1    1.0
# Name: 461, dtype: float32
# 0    1.0
# 1    1.0
# Name: 462, dtype: float32
# 0    1.0
# 1    1.0
# Name: 463, dtype: float32
# 0    1.000000
# 1    0.930691
# Name: 464, dtype: float32
# 0    1.000000
# 1    0.646696
# Name: 465, dtype: float32
# 0    1.00000
# 1    0.60956
# Name: 466, dtype: float32
# 0    1.000000
# 1    0.438198
# Name: 467, dtype: float32
# 0    1.000000
# 1   -0.090916
# Name: 468, dtype: float32
# 0    0.542166
# 1   -0.128352
# Name: 469, dtype: float32
# 0   -0.524532
# 1   -0.871518
# Name: 470, dtype: float32
# 0   -0.945825
# 1   -1.000000
# Name: 471, dtype: float32
# 0   -0.883535
# 1   -1.000000
# Name: 472, dtype: float32
# 0   -0.903448
# 1   -1.000000
# Name: 473, dtype: float32
# 0   -0.985527
# 1   -1.000000
# Name: 474, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 475, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 476, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 477, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 478, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 479, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 480, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 481, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 482, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 483, dtype: float32
# 0   -1.000000
# 1   -0.880955
# Name: 484, dtype: float32
# 0   -1.000000
# 1   -0.581314
# Name: 485, dtype: float32
# 0   -1.000000
# 1   -0.053431
# Name: 486, dtype: float32
# 0   -0.811617
# 1    0.659189
# Name: 487, dtype: float32
# 0    0.452672
# 1    1.000000
# Name: 488, dtype: float32
# 0    0.896781
# 1    1.000000
# Name: 489, dtype: float32
# 0    0.958117
# 1    1.000000
# Name: 490, dtype: float32
# 0    1.0
# 1    1.0
# Name: 491, dtype: float32
# 0    0.968273
# 1    1.000000
# Name: 492, dtype: float32
# 0    0.936032
# 1    1.000000
# Name: 493, dtype: float32
# 0    1.0
# 1    1.0
# Name: 494, dtype: float32
# 0    1.0
# 1    1.0
# Name: 495, dtype: float32
# 0    1.0
# 1    1.0
# Name: 496, dtype: float32
# 0    1.0
# 1    1.0
# Name: 497, dtype: float32
# 0    1.0
# 1    1.0
# Name: 498, dtype: float32
# 0    1.0
# 1    1.0
# Name: 499, dtype: float32
# 0    1.000000
# 1    0.997568
# Name: 500, dtype: float32
# 0    1.000000
# 1    0.668449
# Name: 501, dtype: float32
# 0    1.000000
# 1    0.606527
# Name: 502, dtype: float32
# 0    1.000000
# 1    0.505143
# Name: 503, dtype: float32
# 0    1.000000
# 1    0.024379
# Name: 504, dtype: float32
# 0    0.781015
# 1   -0.160202
# Name: 505, dtype: float32
# 0   -0.313632
# 1   -0.494364
# Name: 506, dtype: float32
# 0   -0.83816
# 1   -1.00000
# Name: 507, dtype: float32
# 0   -0.858548
# 1   -1.000000
# Name: 508, dtype: float32
# 0   -0.88201
# 1   -1.00000
# Name: 509, dtype: float32
# 0   -0.953687
# 1   -1.000000
# Name: 510, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 511, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 512, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 513, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 514, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 515, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 516, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 517, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 518, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 519, dtype: float32
# 0   -1.000000
# 1   -0.987707
# Name: 520, dtype: float32
# 0   -1.000000
# 1   -0.727924
# Name: 521, dtype: float32
# 0   -1.000000
# 1   -0.308105
# Name: 522, dtype: float32
# 0   -1.000000
# 1    0.233934
# Name: 523, dtype: float32
# 0   -0.15195
# 1    1.00000
# Name: 524, dtype: float32
# 0    0.753257
# 1    1.000000
# Name: 525, dtype: float32
# 0    0.944446
# 1    1.000000
# Name: 526, dtype: float32
# 0    0.982095
# 1    1.000000
# Name: 527, dtype: float32
# 0    1.0
# 1    1.0
# Name: 528, dtype: float32
# 0    0.918078
# 1    1.000000
# Name: 529, dtype: float32
# 0    0.98471
# 1    1.00000
# Name: 530, dtype: float32
# 0    1.0
# 1    1.0
# Name: 531, dtype: float32
# 0    1.0
# 1    1.0
# Name: 532, dtype: float32
# 0    1.0
# 1    1.0
# Name: 533, dtype: float32
# 0    1.0
# 1    1.0
# Name: 534, dtype: float32
# 0    1.0
# 1    1.0
# Name: 535, dtype: float32
# 0    1.0
# 1    1.0
# Name: 536, dtype: float32
# 0    1.0000
# 1    0.8434
# Name: 537, dtype: float32
# 0    1.000000
# 1    0.620431
# Name: 538, dtype: float32
# 0    1.000000
# 1    0.594103
# Name: 539, dtype: float32
# 0    1.000000
# 1    0.326944
# Name: 540, dtype: float32
# 0    1.000000
# 1   -0.186671
# Name: 541, dtype: float32
# 0    0.235737
# 1   -0.127518
# Name: 542, dtype: float32
# 0   -0.689256
# 1   -1.000000
# Name: 543, dtype: float32
# 0   -0.913877
# 1   -1.000000
# Name: 544, dtype: float32
# 0   -0.877768
# 1   -1.000000
# Name: 545, dtype: float32
# 0   -0.918074
# 1   -1.000000
# Name: 546, dtype: float32
# 0   -0.998757
# 1   -1.000000
# Name: 547, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 548, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 549, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 550, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 551, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 552, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 553, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 554, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 555, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 556, dtype: float32
# 0   -1.000000
# 1   -0.834654
# Name: 557, dtype: float32
# 0   -1.000000
# 1   -0.488738
# Name: 558, dtype: float32
# 0   -1.000000
# 1    0.053242
# Name: 559, dtype: float32
# 0   -0.562512
# 1    0.892749
# Name: 560, dtype: float32
# 0    0.627534
# 1    1.000000
# Name: 561, dtype: float32
# 0    0.935903
# 1    1.000000
# Name: 562, dtype: float32
# 0    0.97164
# 1    1.00000
# Name: 563, dtype: float32
# 0    1.0
# 1    1.0
# Name: 564, dtype: float32
# 0    0.944648
# 1    1.000000
# Name: 565, dtype: float32
# 0    0.961003
# 1    1.000000
# Name: 566, dtype: float32
# 0    1.0
# 1    1.0
# Name: 567, dtype: float32
# 0    1.0
# 1    1.0
# Name: 568, dtype: float32
# 0    1.0
# 1    1.0
# Name: 569, dtype: float32
# 0    1.0
# 1    1.0
# Name: 570, dtype: float32
# 0    1.0
# 1    1.0
# Name: 571, dtype: float32
# 0    1.0
# 1    1.0
# Name: 572, dtype: float32
# 0    1.000000
# 1    0.898438
# Name: 573, dtype: float32
# 0    1.000000
# 1    0.630509
# Name: 574, dtype: float32
# 0    1.000000
# 1    0.595626
# Name: 575, dtype: float32
# 0    1.000000
# 1    0.394727
# Name: 576, dtype: float32
# 0    1.000000
# 1   -0.146395
# Name: 577, dtype: float32
# 0    0.413145
# 1   -0.128858
# Name: 578, dtype: float32
# 0   -0.61682
# 1   -1.00000
# Name: 579, dtype: float32
# 0   -0.976317
# 1   -1.000000
# Name: 580, dtype: float32
# 0   -0.896053
# 1   -1.000000
# Name: 581, dtype: float32
# 0   -0.920787
# 1   -1.000000
# Name: 582, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 583, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 584, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 585, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 586, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 587, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 588, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 589, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 590, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 591, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 592, dtype: float32
# 0   -1.000000
# 1   -0.828273
# Name: 593, dtype: float32
# 0   -1.000000
# 1   -0.466567
# Name: 594, dtype: float32
# 0   -1.000000
# 1    0.074596
# Name: 595, dtype: float32
# 0   -0.505393
# 1    0.936374
# Name: 596, dtype: float32
# 0    0.660741
# 1    1.000000
# Name: 597, dtype: float32
# 0    0.946281
# 1    1.000000
# Name: 598, dtype: float32
# 0    0.978134
# 1    1.000000
# Name: 599, dtype: float32
# 0    1.0
# 1    1.0
# Name: 600, dtype: float32
# 0    0.94149
# 1    1.00000
# Name: 601, dtype: float32
# 0    0.970407
# 1    1.000000
# Name: 602, dtype: float32
# 0    1.0
# 1    1.0
# Name: 603, dtype: float32
# 0    1.0
# 1    1.0
# Name: 604, dtype: float32
# 0    1.0
# 1    1.0
# Name: 605, dtype: float32
# 0    1.0
# 1    1.0
# Name: 606, dtype: float32
# 0    1.0
# 1    1.0
# Name: 607, dtype: float32
# 0    1.0
# 1    1.0
# Name: 608, dtype: float32
# 0    1.000000
# 1    0.867929
# Name: 609, dtype: float32
# 0    1.000000
# 1    0.620235
# Name: 610, dtype: float32
# 0    1.000000
# 1    0.589599
# Name: 611, dtype: float32
# 0    1.000000
# 1    0.353783
# Name: 612, dtype: float32
# 0    1.000000
# 1   -0.180128
# Name: 613, dtype: float32
# 0    0.301501
# 1   -0.128173
# Name: 614, dtype: float32
# 0   -0.672606
# 1   -1.000000
# Name: 615, dtype: float32
# 0   -0.942311
# 1   -1.000000
# Name: 616, dtype: float32
# 0   -0.88712
# 1   -1.00000
# Name: 617, dtype: float32
# 0   -0.923454
# 1   -1.000000
# Name: 618, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 619, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 620, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 621, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 622, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 623, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 624, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 625, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 626, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 627, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 628, dtype: float32
# 0   -1.000000
# 1   -0.820575
# Name: 629, dtype: float32
# 0   -1.000000
# 1   -0.445906
# Name: 630, dtype: float32
# 0   -1.000000
# 1    0.093626
# Name: 631, dtype: float32
# 0   -0.457286
# 1    0.970268
# Name: 632, dtype: float32
# 0    0.680799
# 1    1.000000
# Name: 633, dtype: float32
# 0    0.949841
# 1    1.000000
# Name: 634, dtype: float32
# 0    0.980529
# 1    1.000000
# Name: 635, dtype: float32
# 0    1.0
# 1    1.0
# Name: 636, dtype: float32
# 0    0.938082
# 1    1.000000
# Name: 637, dtype: float32
# 0    0.974296
# 1    1.000000
# Name: 638, dtype: float32
# 0    1.0
# 1    1.0
# Name: 639, dtype: float32
# 0    1.0
# 1    1.0
# Name: 640, dtype: float32
# 0    1.0
# 1    1.0
# Name: 641, dtype: float32
# 0    1.0
# 1    1.0
# Name: 642, dtype: float32
# 0    1.0
# 1    1.0
# Name: 643, dtype: float32
# 0    1.0
# 1    1.0
# Name: 644, dtype: float32
# 0    1.000000
# 1    0.853086
# Name: 645, dtype: float32
# 0    1.000000
# 1    0.613702
# Name: 646, dtype: float32
# 0    1.0000
# 1    0.5835
# Name: 647, dtype: float32
# 0    1.000000
# 1    0.331224
# Name: 648, dtype: float32
# 0    1.000000
# 1   -0.195893
# Name: 649, dtype: float32
# 0    0.246656
# 1   -0.131077
# Name: 650, dtype: float32
# 0   -0.696915
# 1   -1.000000
# Name: 651, dtype: float32
# 0   -0.929404
# 1   -1.000000
# Name: 652, dtype: float32
# 0   -0.885604
# 1   -1.000000
# Name: 653, dtype: float32
# 0   -0.926835
# 1   -1.000000
# Name: 654, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 655, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 656, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 657, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 658, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 659, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 660, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 661, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 662, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 663, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 664, dtype: float32
# 0   -1.00000
# 1   -0.81349
# Name: 665, dtype: float32
# 0   -1.000000
# 1   -0.425474
# Name: 666, dtype: float32
# 0   -1.000000
# 1    0.111637
# Name: 667, dtype: float32
# 0   -0.411487
# 1    0.999719
# Name: 668, dtype: float32
# 0    0.697937
# 1    1.000000
# Name: 669, dtype: float32
# 0    0.952763
# 1    1.000000
# Name: 670, dtype: float32
# 0    0.982794
# 1    1.000000
# Name: 671, dtype: float32
# 0    1.0
# 1    1.0
# Name: 672, dtype: float32
# 0    0.93507
# 1    1.00000
# Name: 673, dtype: float32
# 0    0.977972
# 1    1.000000
# Name: 674, dtype: float32
# 0    1.0
# 1    1.0
# Name: 675, dtype: float32
# 0    1.0
# 1    1.0
# Name: 676, dtype: float32
# 0    1.0
# 1    1.0
# Name: 677, dtype: float32
# 0    1.0
# 1    1.0
# Name: 678, dtype: float32
# 0    1.0
# 1    1.0
# Name: 679, dtype: float32
# 0    1.0
# 1    1.0
# Name: 680, dtype: float32
# 0    1.000000
# 1    0.839164
# Name: 681, dtype: float32
# 0    1.000000
# 1    0.607198
# Name: 682, dtype: float32
# 0    1.000000
# 1    0.576926
# Name: 683, dtype: float32
# 0    1.000000
# 1    0.308986
# Name: 684, dtype: float32
# 0    1.000000
# 1   -0.209223
# Name: 685, dtype: float32
# 0    0.196268
# 1   -0.135061
# Name: 686, dtype: float32
# 0   -0.717263
# 1   -1.000000
# Name: 687, dtype: float32
# 0   -0.919419
# 1   -1.000000
# Name: 688, dtype: float32
# 0   -0.885176
# 1   -1.000000
# Name: 689, dtype: float32
# 0   -0.930636
# 1   -1.000000
# Name: 690, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 691, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 692, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 693, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 694, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 695, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 696, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 697, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 698, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 699, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 700, dtype: float32
# 0   -1.00000
# 1   -0.80582
# Name: 701, dtype: float32
# 0   -1.00000
# 1   -0.40367
# Name: 702, dtype: float32
# 0   -1.000000
# 1    0.130358
# Name: 703, dtype: float32
# 0   -0.364486
# 1    1.000000
# Name: 704, dtype: float32
# 0    0.703468
# 1    1.000000
# Name: 705, dtype: float32
# 0    0.949135
# 1    1.000000
# Name: 706, dtype: float32
# 0    0.981117
# 1    1.000000
# Name: 707, dtype: float32
# 0    1.0
# 1    1.0
# Name: 708, dtype: float32
# 0    0.932294
# 1    1.000000
# Name: 709, dtype: float32
# 0    0.977913
# 1    1.000000
# Name: 710, dtype: float32
# 0    1.0
# 1    1.0
# Name: 711, dtype: float32
# 0    1.0
# 1    1.0
# Name: 712, dtype: float32
# 0    1.0
# 1    1.0
# Name: 713, dtype: float32
# 0    1.0
# 1    1.0
# Name: 714, dtype: float32
# 0    1.0
# 1    1.0
# Name: 715, dtype: float32
# 0    1.0
# 1    1.0
# Name: 716, dtype: float32
# 0    1.000000
# 1    0.836337
# Name: 717, dtype: float32
# 0    1.000000
# 1    0.603686
# Name: 718, dtype: float32
# 0    1.000000
# 1    0.572489
# Name: 719, dtype: float32
# 0    1.000000
# 1    0.303368
# Name: 720, dtype: float32
# 0    1.000000
# 1   -0.215541
# Name: 721, dtype: float32
# 0    0.184991
# 1   -0.138178
# Name: 722, dtype: float32
# 0   -0.724597
# 1   -1.000000
# Name: 723, dtype: float32
# 0   -0.919643
# 1   -1.000000
# Name: 724, dtype: float32
# 0   -0.886391
# 1   -1.000000
# Name: 725, dtype: float32
# 0   -0.933171
# 1   -1.000000
# Name: 726, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 727, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 728, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 729, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 730, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 731, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 732, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 733, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 734, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 735, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 736, dtype: float32
# 0   -1.000000
# 1   -0.801056
# Name: 737, dtype: float32
# 0   -1.000000
# 1   -0.386545
# Name: 738, dtype: float32
# 0   -1.00000
# 1    0.14464
# Name: 739, dtype: float32
# 0   -0.328087
# 1    1.000000
# Name: 740, dtype: float32
# 0    0.708011
# 1    1.000000
# Name: 741, dtype: float32
# 0    0.947013
# 1    1.000000
# Name: 742, dtype: float32
# 0    0.980488
# 1    1.000000
# Name: 743, dtype: float32
# 0    1.0
# 1    1.0
# Name: 744, dtype: float32
# 0    0.930456
# 1    1.000000
# Name: 745, dtype: float32
# 0    0.978691
# 1    1.000000
# Name: 746, dtype: float32
# 0    1.0
# 1    1.0
# Name: 747, dtype: float32
# 0    1.0
# 1    1.0
# Name: 748, dtype: float32
# 0    1.0
# 1    1.0
# Name: 749, dtype: float32
# 0    1.0
# 1    1.0
# Name: 750, dtype: float32
# 0    1.0
# 1    1.0
# Name: 751, dtype: float32
# 0    1.0
# 1    1.0
# Name: 752, dtype: float32
# 0    1.000000
# 1    0.831482
# Name: 753, dtype: float32
# 0    1.000000
# 1    0.599816
# Name: 754, dtype: float32
# 0    1.000000
# 1    0.567869
# Name: 755, dtype: float32
# 0    1.000000
# 1    0.294614
# Name: 756, dtype: float32
# 0    1.000000
# 1   -0.222495
# Name: 757, dtype: float32
# 0    0.166958
# 1   -0.141399
# Name: 758, dtype: float32
# 0   -0.733534
# 1   -1.000000
# Name: 759, dtype: float32
# 0   -0.91821
# 1   -1.00000
# Name: 760, dtype: float32
# 0   -0.887327
# 1   -1.000000
# Name: 761, dtype: float32
# 0   -0.935857
# 1   -1.000000
# Name: 762, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 763, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 764, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 765, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 766, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 767, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 768, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 769, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 770, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 771, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 772, dtype: float32
# 0   -1.000000
# 1   -0.795664
# Name: 773, dtype: float32
# 0   -1.000000
# 1   -0.369254
# Name: 774, dtype: float32
# 0   -1.00000
# 1    0.15913
# Name: 775, dtype: float32
# 0   -0.292324
# 1    1.000000
# Name: 776, dtype: float32
# 0    0.71233
# 1    1.00000
# Name: 777, dtype: float32
# 0    0.944966
# 1    1.000000
# Name: 778, dtype: float32
# 0    0.979932
# 1    1.000000
# Name: 779, dtype: float32
# 0    1.0
# 1    1.0
# Name: 780, dtype: float32
# 0    0.928602
# 1    1.000000
# Name: 781, dtype: float32
# 0    0.979437
# 1    1.000000
# Name: 782, dtype: float32
# 0    1.0
# 1    1.0
# Name: 783, dtype: float32
# 0    1.0
# 1    1.0
# Name: 784, dtype: float32
# 0    1.0
# 1    1.0
# Name: 785, dtype: float32
# 0    1.0
# 1    1.0
# Name: 786, dtype: float32
# 0    1.0
# 1    1.0
# Name: 787, dtype: float32
# 0    1.0
# 1    1.0
# Name: 788, dtype: float32
# 0    1.00000
# 1    0.82707
# Name: 789, dtype: float32
# 0    1.000000
# 1    0.596189
# Name: 790, dtype: float32
# 0    1.00000
# 1    0.56349
# Name: 791, dtype: float32
# 0    1.000000
# 1    0.286531
# Name: 792, dtype: float32
# 0    1.000000
# 1   -0.228874
# Name: 793, dtype: float32
# 0    0.150728
# 1   -0.144516
# Name: 794, dtype: float32
# 0   -0.741609
# 1   -1.000000
# Name: 795, dtype: float32
# 0   -0.917185
# 1   -1.000000
# Name: 796, dtype: float32
# 0   -0.88828
# 1   -1.00000
# Name: 797, dtype: float32
# 0   -0.938395
# 1   -1.000000
# Name: 798, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 799, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 800, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 801, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 802, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 803, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 804, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 805, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 806, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 807, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 808, dtype: float32
# 0   -1.000000
# 1   -0.790404
# Name: 809, dtype: float32
# 0   -1.000000
# 1   -0.352859
# Name: 810, dtype: float32
# 0   -1.00000
# 1    0.17298
# Name: 811, dtype: float32
# 0   -0.259031
# 1    1.000000
# Name: 812, dtype: float32
# 0    0.716365
# 1    1.000000
# Name: 813, dtype: float32
# 0    0.943248
# 1    1.000000
# Name: 814, dtype: float32
# 0    0.9796
# 1    1.0000
# Name: 815, dtype: float32
# 0    1.0
# 1    1.0
# Name: 816, dtype: float32
# 0    0.926907
# 1    1.000000
# Name: 817, dtype: float32
# 0    0.980305
# 1    1.000000
# Name: 818, dtype: float32
# 0    1.0
# 1    1.0
# Name: 819, dtype: float32
# 0    1.0
# 1    1.0
# Name: 820, dtype: float32
# 0    1.0
# 1    1.0
# Name: 821, dtype: float32
# 0    1.0
# 1    1.0
# Name: 822, dtype: float32
# 0    1.0
# 1    1.0
# Name: 823, dtype: float32
# 0    1.0
# 1    1.0
# Name: 824, dtype: float32
# 0    1.000000
# 1    0.822587
# Name: 825, dtype: float32
# 0    1.000000
# 1    0.592649
# Name: 826, dtype: float32
# 0    1.000000
# 1    0.559231
# Name: 827, dtype: float32
# 0    1.000000
# 1    0.278293
# Name: 828, dtype: float32
# 0    1.000000
# 1   -0.234947
# Name: 829, dtype: float32
# 0    0.134481
# 1   -0.147591
# Name: 830, dtype: float32
# 0   -0.749381
# 1   -1.000000
# Name: 831, dtype: float32
# 0   -0.916164
# 1   -1.000000
# Name: 832, dtype: float32
# 0   -0.889211
# 1   -1.000000
# Name: 833, dtype: float32
# 0   -0.940874
# 1   -1.000000
# Name: 834, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 835, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 836, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 837, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 838, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 839, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 840, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 841, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 842, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 843, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 844, dtype: float32
# 0   -1.000000
# 1   -0.785057
# Name: 845, dtype: float32
# 0   -1.000000
# 1   -0.337032
# Name: 846, dtype: float32
# 0   -1.00000
# 1    0.18659
# Name: 847, dtype: float32
# 0   -0.227359
# 1    1.000000
# Name: 848, dtype: float32
# 0    0.720233
# 1    1.000000
# Name: 849, dtype: float32
# 0    0.941767
# 1    1.000000
# Name: 850, dtype: float32
# 0    0.979431
# 1    1.000000
# Name: 851, dtype: float32
# 0    1.0
# 1    1.0
# Name: 852, dtype: float32
# 0    0.925306
# 1    1.000000
# Name: 853, dtype: float32
# 0    0.981258
# 1    1.000000
# Name: 854, dtype: float32
# 0    1.0
# 1    1.0
# Name: 855, dtype: float32
# 0    1.0
# 1    1.0
# Name: 856, dtype: float32
# 0    1.0
# 1    1.0
# Name: 857, dtype: float32
# 0    1.0
# 1    1.0
# Name: 858, dtype: float32
# 0    1.0
# 1    1.0
# Name: 859, dtype: float32
# 0    1.0
# 1    1.0
# Name: 860, dtype: float32
# 0    1.000000
# 1    0.818111
# Name: 861, dtype: float32
# 0    1.000000
# 1    0.589203
# Name: 862, dtype: float32
# 0    1.000000
# 1    0.555089
# Name: 863, dtype: float32
# 0    1.000000
# 1    0.270016
# Name: 864, dtype: float32
# 0    1.0000
# 1   -0.2407
# Name: 865, dtype: float32
# 0    0.118475
# 1   -0.150631
# Name: 866, dtype: float32
# 0   -0.756815
# 1   -1.000000
# Name: 867, dtype: float32
# 0   -0.915207
# 1   -1.000000
# Name: 868, dtype: float32
# 0   -0.890136
# 1   -1.000000
# Name: 869, dtype: float32
# 0   -0.943293
# 1   -1.000000
# Name: 870, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 871, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 872, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 873, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 874, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 875, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 876, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 877, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 878, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 879, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 880, dtype: float32
# 0   -1.000000
# 1   -0.779641
# Name: 881, dtype: float32
# 0   -1.00000
# 1   -0.32178
# Name: 882, dtype: float32
# 0   -1.00000
# 1    0.20002
# Name: 883, dtype: float32
# 0   -0.197167
# 1    1.000000
# Name: 884, dtype: float32
# 0    0.723974
# 1    1.000000
# Name: 885, dtype: float32
# 0    0.940505
# 1    1.000000
# Name: 886, dtype: float32
# 0    0.979409
# 1    1.000000
# Name: 887, dtype: float32
# 0    1.0
# 1    1.0
# Name: 888, dtype: float32
# 0    0.92379
# 1    1.00000
# Name: 889, dtype: float32
# 0    0.982293
# 1    1.000000
# Name: 890, dtype: float32
# 0    1.0
# 1    1.0
# Name: 891, dtype: float32
# 0    1.0
# 1    1.0
# Name: 892, dtype: float32
# 0    1.0
# 1    1.0
# Name: 893, dtype: float32
# 0    1.0
# 1    1.0
# Name: 894, dtype: float32
# 0    1.0
# 1    1.0
# Name: 895, dtype: float32
# 0    1.0
# 1    1.0
# Name: 896, dtype: float32
# 0    1.000000
# 1    0.813612
# Name: 897, dtype: float32
# 0    1.000000
# 1    0.585826
# Name: 898, dtype: float32
# 0    1.00000
# 1    0.55104
# Name: 899, dtype: float32
# 0    1.000000
# 1    0.261641
# Name: 900, dtype: float32
# 0    1.000000
# 1   -0.246161
# Name: 901, dtype: float32
# 0    0.102590
# 1   -0.153651
# Name: 902, dtype: float32
# 0   -0.763972
# 1   -1.000000
# Name: 903, dtype: float32
# 0   -0.9143
# 1   -1.0000
# Name: 904, dtype: float32
# 0   -0.891059
# 1   -1.000000
# Name: 905, dtype: float32
# 0   -0.945668
# 1   -1.000000
# Name: 906, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 907, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 908, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 909, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 910, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 911, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 912, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 913, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 914, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 915, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 916, dtype: float32
# 0   -1.000000
# 1   -0.774119
# Name: 917, dtype: float32
# 0   -1.000000
# 1   -0.307033
# Name: 918, dtype: float32
# 0   -1.000000
# 1    0.213392
# Name: 919, dtype: float32
# 0   -0.168178
# 1    1.000000
# Name: 920, dtype: float32
# 0    0.727635
# 1    1.000000
# Name: 921, dtype: float32
# 0    0.939437
# 1    1.000000
# Name: 922, dtype: float32
# 0    0.979518
# 1    1.000000
# Name: 923, dtype: float32
# 0    1.0
# 1    1.0
# Name: 924, dtype: float32
# 0    0.922346
# 1    1.000000
# Name: 925, dtype: float32
# 0    0.983408
# 1    1.000000
# Name: 926, dtype: float32
# 0    1.0
# 1    1.0
# Name: 927, dtype: float32
# 0    1.0
# 1    1.0
# Name: 928, dtype: float32
# 0    1.0
# 1    1.0
# Name: 929, dtype: float32
# 0    1.0
# 1    1.0
# Name: 930, dtype: float32
# 0    1.0
# 1    1.0
# Name: 931, dtype: float32
# 0    1.0
# 1    1.0
# Name: 932, dtype: float32
# 0    1.000000
# 1    0.809075
# Name: 933, dtype: float32
# 0    1.000000
# 1    0.582505
# Name: 934, dtype: float32
# 0    1.000000
# 1    0.547065
# Name: 935, dtype: float32
# 0    1.000000
# 1    0.253131
# Name: 936, dtype: float32
# 0    1.000000
# 1   -0.251348
# Name: 937, dtype: float32
# 0    0.086763
# 1   -0.156667
# Name: 938, dtype: float32
# 0   -0.770894
# 1   -1.000000
# Name: 939, dtype: float32
# 0   -0.913439
# 1   -1.000000
# Name: 940, dtype: float32
# 0   -0.891988
# 1   -1.000000
# Name: 941, dtype: float32
# 0   -0.948012
# 1   -1.000000
# Name: 942, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 943, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 944, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 945, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 946, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 947, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 948, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 949, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 950, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 951, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 952, dtype: float32
# 0   -1.000000
# 1   -0.768465
# Name: 953, dtype: float32
# 0   -1.000000
# 1   -0.292736
# Name: 954, dtype: float32
# 0   -1.000000
# 1    0.226798
# Name: 955, dtype: float32
# 0   -0.140178
# 1    1.000000
# Name: 956, dtype: float32
# 0    0.731251
# 1    1.000000
# Name: 957, dtype: float32
# 0    0.938542
# 1    1.000000
# Name: 958, dtype: float32
# 0    0.979743
# 1    1.000000
# Name: 959, dtype: float32
# 0    1.0
# 1    1.0
# Name: 960, dtype: float32
# 0    0.92096
# 1    1.00000
# Name: 961, dtype: float32
# 0    0.9846
# 1    1.0000
# Name: 962, dtype: float32
# 0    1.0
# 1    1.0
# Name: 963, dtype: float32
# 0    1.0
# 1    1.0
# Name: 964, dtype: float32
# 0    1.0
# 1    1.0
# Name: 965, dtype: float32
# 0    1.0
# 1    1.0
# Name: 966, dtype: float32
# 0    1.0
# 1    1.0
# Name: 967, dtype: float32
# 0    1.0
# 1    1.0
# Name: 968, dtype: float32
# 0    1.000000
# 1    0.804485
# Name: 969, dtype: float32
# 0    1.000000
# 1    0.579222
# Name: 970, dtype: float32
# 0    1.000000
# 1    0.543146
# Name: 971, dtype: float32
# 0    1.000000
# 1    0.244449
# Name: 972, dtype: float32
# 0    1.000000
# 1   -0.256275
# Name: 973, dtype: float32
# 0    0.070930
# 1   -0.159691
# Name: 974, dtype: float32
# 0   -0.777619
# 1   -1.000000
# Name: 975, dtype: float32
# 0   -0.912621
# 1   -1.000000
# Name: 976, dtype: float32
# 0   -0.892929
# 1   -1.000000
# Name: 977, dtype: float32
# 0   -0.950335
# 1   -1.000000
# Name: 978, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 979, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 980, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 981, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 982, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 983, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 984, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 985, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 986, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 987, dtype: float32
# 0   -1.0
# 1   -1.0
# Name: 988, dtype: float32
# 0   -1.000000
# 1   -0.762651
# Name: 989, dtype: float32
# 0   -1.000000
# 1   -0.278835
# Name: 990, dtype: float32
# 0   -1.000000
# 1    0.240326
# Name: 991, dtype: float32
# 0   -0.112969
# 1    1.000000
# Name: 992, dtype: float32
# 0    0.734851
# 1    1.000000
# Name: 993, dtype: float32
# 0    0.937801
# 1    1.000000
# Name: 994, dtype: float32
# 0    0.980075
# 1    1.000000
# Name: 995, dtype: float32
# 0    1.0
# 1    1.0
# Name: 996, dtype: float32
# 0    0.919622
# 1    1.000000
# Name: 997, dtype: float32
# 0    0.985869
# 1    1.000000
# Name: 998, dtype: float32
# 0    1.0
# 1    1.0
# Name: 999, dtype: float32

# %% [markdown]
# # 원래대로

# %%
import torch

# Convert combined_arr to PyTorch Tensor
combined_tensor = torch.from_numpy(combined_arr)

# Print the shape of combined_tensor
print(combined_tensor.shape)

# %%
# import os
# import pandas as pd
# from tqdm import tqdm  # Import tqdm

# output_dir = os.path.join(".", "output")  # Path to the output directory
# subdirs = [f.path for f in os.scandir(output_dir) if f.is_dir()]
# combined_df = pd.DataFrame()

# # Create a tqdm progress bar
# pbar = tqdm(subdirs, desc="Processing subdirectories", unit="subdir")

# for subdir in pbar:
#     action_filename = os.path.join(subdir, "action.csv")
#     obs_filename = os.path.join(subdir, "obs.csv")
#     action_df = pd.read_csv(action_filename)
#     obs_df = pd.read_csv(obs_filename)
#     combined_data = pd.concat([action_df, obs_df], axis=1)
#     if combined_data.shape == (999,10):
#         combined_df = pd.concat([combined_df, combined_data], ignore_index=True)
#     else:
#         print("fail : ", subdir)

#     # Update the progress bar
#     pbar.set_postfix({"Processed subdirectories": subdir})

# # Close the progress bar
# pbar.close()

# %% [markdown]
# # VAE code -1

# %%
class Encoder(nn.Module):
    def __init__(self, input_shape, hidden_dim1, hidden_dim2, hidden_dim3, latent_dim):
        super(Encoder, self).__init__()
        
        self.encoder = nn.Sequential(
            nn.Linear(input_shape, hidden_dim1),
            nn.ReLU(),
            nn.Linear(hidden_dim1, hidden_dim2),
            nn.ReLU(),
            nn.Linear(hidden_dim2, hidden_dim3),
            nn.ReLU(),
            nn.Linear(hidden_dim3, latent_dim * 2)  # mean and variance
        )

    def forward(self, x):
        h = self.encoder(x)
        mu, log_var = h.chunk(2, dim=1)
        return mu, log_var


class Decoder(nn.Module):
    def __init__(self, latent_dim, hidden_dim1, hidden_dim2, hidden_dim3, output_shape):
        super(Decoder, self).__init__()

        self.decoder = nn.Sequential(
            nn.Linear(latent_dim, hidden_dim3),
            nn.ReLU(),
            nn.Linear(hidden_dim3, hidden_dim2),
            nn.ReLU(),
            nn.Linear(hidden_dim2, hidden_dim1),
            nn.ReLU(),
            nn.Linear(hidden_dim1, output_shape),
        )

    def forward(self, z):
        x_reconstructed = self.decoder(z)
        return x_reconstructed


class VAE(nn.Module):
    def __init__(self, input_shape, hidden_dim1, hidden_dim2, hidden_dim3, latent_dim):
        super(VAE, self).__init__()

        self.encoder = Encoder(input_shape, hidden_dim1, hidden_dim2, hidden_dim3, latent_dim)
        self.decoder = Decoder(latent_dim, hidden_dim1, hidden_dim2, hidden_dim3, input_shape)

    def reparameterize(self, mu, log_var):
        std = torch.exp(log_var / 2)
        eps = torch.randn_like(std)
        return mu + eps * std

    def forward(self, x):
        mu, log_var = self.encoder(x)
        z = self.reparameterize(mu, log_var)
        x_reconstructed = self.decoder(z)
        return x_reconstructed, mu, log_var

    
import torch
from torch import nn
from torch import optim
from torch.utils.data import DataLoader, TensorDataset
from torch.utils.data.dataset import random_split

# Assuming combined_tensor is your data
# Convert the data to float32
dataset = TensorDataset(combined_tensor.float())

# Define the data loader
batch_size = 256  # adjust as necessary

# Split data into train, validation, and test
train_size = int(0.7 * len(dataset))  # 70% for training
valid_size = int(0.15 * len(dataset))  # 15% for validation
test_size = len(dataset) - train_size - valid_size  # 15% for testing

train_dataset, valid_dataset, test_dataset = random_split(dataset, [train_size, valid_size, test_size])

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
valid_loader = DataLoader(valid_dataset, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=True)

# Hyperparameters
input_shape = combined_tensor.shape[1] * combined_tensor.shape[2]  # modify this to match your data
hidden_dim1 = 512  # modify as needed
hidden_dim2 = 128  # modify as needed
hidden_dim3 = 24  # modify as needed
latent_dim = 2  # modify as needed
lr = 1e-3  # learning rate
n_epochs = 100  # modify as needed
beta = 0.2
    
# Model, optimizer, and loss function
model = VAE(input_shape, hidden_dim1, hidden_dim2, hidden_dim3, latent_dim)

optimizer = optim.Adam(model.parameters(), lr=lr)  # Make sure you're using the correct optimizer
loss_fn = nn.MSELoss()  # And the correct loss function


def train(epoch, model, optimizer, loss_fn, train_loader):
    model.train()
    train_loss = 0
    total_recon_loss = 0
    total_kl_div = 0
    for i, batch in enumerate(train_loader):  # using train_loader instead of dataloader
        batch_data = batch[0]  # get the data from the batch
        
        optimizer.zero_grad()

        # Flatten the data
        batch_data = batch_data.view(batch_data.size(0), -1)

        reconstructed_batch, mu, log_var = model(batch_data)

        # Loss: reconstruction loss + KL divergence
        recon_loss = loss_fn(reconstructed_batch, batch_data)
        kl_divergence = -0.5 * torch.sum(1 + log_var - mu.pow(2) - log_var.exp())
        loss = recon_loss + beta*kl_divergence

        loss.backward()
        train_loss += loss.item()
        total_recon_loss += recon_loss.item()
        total_kl_div += kl_divergence.item()
        optimizer.step()

    avg_loss = train_loss / len(train_loader.dataset)
    avg_recon_loss = total_recon_loss / len(train_loader.dataset)
    avg_kl_div = total_kl_div / len(train_loader.dataset)
    print(f'====> Epoch: {epoch} Average loss: {avg_loss}, Recon Loss: {avg_recon_loss}, KL Div: {avg_kl_div}')

    return avg_loss, avg_recon_loss, avg_kl_div

    
import matplotlib.pyplot as plt

# Lists to store losses for each epoch
avg_losses = []
avg_recon_losses = []
avg_kl_divs = []

# Training
for epoch in range(1, n_epochs + 1):
    avg_loss, avg_recon_loss, avg_kl_div = train(epoch, model, optimizer, loss_fn, train_loader)
    avg_losses.append(avg_loss)
    avg_recon_losses.append(avg_recon_loss)
    avg_kl_divs.append(avg_kl_div)

# Plot the losses
plt.figure(figsize=(7,5))
plt.plot(avg_losses, label='Average Loss')
plt.plot(avg_recon_losses, label='Reconstruction Loss')
plt.plot(avg_kl_divs, label='KL Divergence')
plt.title('Losses')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# ====> Epoch: 1 Average loss: 0.022717866352626254, Recon Loss: 0.008911648716245378, KL Div: 0.0690310868876321
# ====> Epoch: 2 Average loss: 0.009382953643798828, Recon Loss: 0.008009764569146293, KL Div: 0.006865945679800851
# ====> Epoch: 3 Average loss: 0.00890677285194397, Recon Loss: 0.008028668625014168, KL Div: 0.004390521151678903
# ====> Epoch: 4 Average loss: 0.008549687010901315, Recon Loss: 0.008028507402965, KL Div: 0.0026058978693825857
# ====> Epoch: 5 Average loss: 0.008260311654635838, Recon Loss: 0.00796705504826137, KL Div: 0.001466283014842442
# ====> Epoch: 6 Average loss: 0.008176799433571951, Recon Loss: 0.008019766398838588, KL Div: 0.0007851654802049909
# ====> Epoch: 7 Average loss: 0.008066347530909948, Recon Loss: 0.00798635252884456, KL Div: 0.00039997482299804687
# ====> Epoch: 8 Average loss: 0.008061358434813364, Recon Loss: 0.008022653528622218, KL Div: 0.00019352446283612933
# ====> Epoch: 9 Average loss: 0.008056209717478072, Recon Loss: 0.00803847348690033, KL Div: 8.868122100830079e-05
# ====> Epoch: 10 Average loss: 0.008000344957624164, Recon Loss: 0.007992657831736973, KL Div: 3.843515259878976e-05
# ====> Epoch: 11 Average loss: 0.00802202124255044, Recon Loss: 0.008018877557345799, KL Div: 1.571835790361677e-05
# ====> Epoch: 12 Average loss: 0.008032530171530588, Recon Loss: 0.008031324556895664, KL Div: 6.0278347560337615e-06
# ====> Epoch: 13 Average loss: 0.008017974036080497, Recon Loss: 0.008017533336366926, KL Div: 2.2031920296805246e-06
# ====> Epoch: 14 Average loss: 0.00802134222643716, Recon Loss: 0.008021188565662928, KL Div: 7.681846618652344e-07
# ====> Epoch: 15 Average loss: 0.00799295699596405, Recon Loss: 0.007992907234600612, KL Div: 2.4890899658203126e-07
# ====> Epoch: 16 Average loss: 0.00802069343839373, Recon Loss: 0.008020678077425276, KL Div: 7.66686030796596e-08
# ====> Epoch: 17 Average loss: 0.008009612134524753, Recon Loss: 0.008009607672691346, KL Div: 2.288818359375e-08
# ====> Epoch: 18 Average loss: 0.007996594514165605, Recon Loss: 0.007996594514165605, KL Div: 0.0
# ====> Epoch: 19 Average loss: 0.00800975068977901, Recon Loss: 0.00800975068977901, KL Div: 0.0
# ====> Epoch: 20 Average loss: 0.008011206933430264, Recon Loss: 0.00801120672907148, KL Div: 1.0899135044642858e-09
# ====> Epoch: 21 Average loss: 0.007998808673449926, Recon Loss: 0.007998808673449926, KL Div: 0.0
# ====> Epoch: 22 Average loss: 0.00798474565574101, Recon Loss: 0.00798474565574101, KL Div: 0.0
# ====> Epoch: 23 Average loss: 0.008015622070857457, Recon Loss: 0.008015622070857457, KL Div: 0.0
# ====> Epoch: 24 Average loss: 0.007998532124928065, Recon Loss: 0.007998532124928065, KL Div: 0.0
# ====> Epoch: 25 Average loss: 0.007985230599130902, Recon Loss: 0.007985230599130902, KL Div: 0.0
# ====> Epoch: 26 Average loss: 0.008037505779947553, Recon Loss: 0.008037505779947553, KL Div: 0.0
# ====> Epoch: 27 Average loss: 0.008013135467256818, Recon Loss: 0.008013135467256818, KL Div: 0.0
# ====> Epoch: 28 Average loss: 0.007993020858083453, Recon Loss: 0.00799302065372467, KL Div: 1.0899135044642858e-09
# ====> Epoch: 29 Average loss: 0.008009214588574001, Recon Loss: 0.008009214588574001, KL Div: 0.0
# ====> Epoch: 30 Average loss: 0.007999730961663383, Recon Loss: 0.007999730961663383, KL Div: 0.0
# ====> Epoch: 31 Average loss: 0.00803527751990727, Recon Loss: 0.008035277298518589, KL Div: 1.0899135044642858e-09
# ====> Epoch: 32 Average loss: 0.007994665111814226, Recon Loss: 0.00799466449873788, KL Div: 3.269740513392857e-09
# ====> Epoch: 33 Average loss: 0.007982440539768765, Recon Loss: 0.007982440539768765, KL Div: 0.0
# ====> Epoch: 34 Average loss: 0.007995156509535653, Recon Loss: 0.007995156509535653, KL Div: 0.0
# ====> Epoch: 35 Average loss: 0.008027360251971654, Recon Loss: 0.008027360251971654, KL Div: 0.0
# ====> Epoch: 36 Average loss: 0.008009472131729126, Recon Loss: 0.008009471927370344, KL Div: 1.0899135044642858e-09
# ====> Epoch: 37 Average loss: 0.008011186684880938, Recon Loss: 0.008011186684880938, KL Div: 0.0
# ====> Epoch: 38 Average loss: 0.008000706485339574, Recon Loss: 0.008000706485339574, KL Div: 0.0
# ====> Epoch: 39 Average loss: 0.008022034764289856, Recon Loss: 0.008022034321512495, KL Div: 2.1798270089285716e-09
# ====> Epoch: 40 Average loss: 0.007997044546263559, Recon Loss: 0.007997044324874879, KL Div: 1.0899135044642858e-09
# ====> Epoch: 41 Average loss: 0.008011999981743949, Recon Loss: 0.008011999981743949, KL Div: 0.0
# ====> Epoch: 42 Average loss: 0.007998600023133413, Recon Loss: 0.007998600023133413, KL Div: 0.0
# [E thread_pool.cpp:109] Exception in thread pool task: mutex lock failed: Invalid argument
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[108], line 143
#     141 # Training
#     142 for epoch in range(1, n_epochs + 1):
# --> 143     avg_loss, avg_recon_loss, avg_kl_div = train(epoch, model, optimizer, loss_fn, train_loader)
#     144     avg_losses.append(avg_loss)
#     145     avg_recon_losses.append(avg_recon_loss)
#
# Cell In[108], line 124, in train(epoch, model, optimizer, loss_fn, train_loader)
#     122     total_recon_loss += recon_loss.item()
#     123     total_kl_div += kl_divergence.item()
# --> 124     optimizer.step()
#     126 avg_loss = train_loss / len(train_loader.dataset)
#     127 avg_recon_loss = total_recon_loss / len(train_loader.dataset)
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/firstenv/lib/python3.11/site-packages/torch/optim/optimizer.py:280, in Optimizer.profile_hook_step.<locals>.wrapper(*args, **kwargs)
#     276         else:
#     277             raise RuntimeError(f"{func} must return None or a tuple of (new_args, new_kwargs),"
#     278                                f"but got {result}.")
# --> 280 out = func(*args, **kwargs)
#     281 self._optimizer_step_code()
#     283 # call optimizer step post hooks
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/firstenv/lib/python3.11/site-packages/torch/optim/optimizer.py:33, in _use_grad_for_differentiable.<locals>._use_grad(self, *args, **kwargs)
#      31 try:
#      32     torch.set_grad_enabled(self.defaults['differentiable'])
# ---> 33     ret = func(self, *args, **kwargs)
#      34 finally:
#      35     torch.set_grad_enabled(prev_grad)
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/firstenv/lib/python3.11/site-packages/torch/optim/adam.py:141, in Adam.step(self, closure)
#     130     beta1, beta2 = group['betas']
#     132     self._init_group(
#     133         group,
#     134         params_with_grad,
#    (...)
#     138         max_exp_avg_sqs,
#     139         state_steps)
# --> 141     adam(
#     142         params_with_grad,
#     143         grads,
#     144         exp_avgs,
#     145         exp_avg_sqs,
#     146         max_exp_avg_sqs,
#     147         state_steps,
#     148         amsgrad=group['amsgrad'],
#     149         beta1=beta1,
#     150         beta2=beta2,
#     151         lr=group['lr'],
#     152         weight_decay=group['weight_decay'],
#     153         eps=group['eps'],
#     154         maximize=group['maximize'],
#     155         foreach=group['foreach'],
#     156         capturable=group['capturable'],
#     157         differentiable=group['differentiable'],
#     158         fused=group['fused'],
#     159         grad_scale=getattr(self, "grad_scale", None),
#     160         found_inf=getattr(self, "found_inf", None),
#     161     )
#     163 return loss
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/firstenv/lib/python3.11/site-packages/torch/optim/adam.py:281, in adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, foreach, capturable, differentiable, fused, grad_scale, found_inf, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize)
#     278 else:
#     279     func = _single_tensor_adam
# --> 281 func(params,
#     282      grads,
#     283      exp_avgs,
#     284      exp_avg_sqs,
#     285      max_exp_avg_sqs,
#     286      state_steps,
#     287      amsgrad=amsgrad,
#     288      beta1=beta1,
#     289      beta2=beta2,
#     290      lr=lr,
#     291      weight_decay=weight_decay,
#     292      eps=eps,
#     293      maximize=maximize,
#     294      capturable=capturable,
#     295      differentiable=differentiable,
#     296      grad_scale=grad_scale,
#     297      found_inf=found_inf)
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/firstenv/lib/python3.11/site-packages/torch/optim/adam.py:393, in _single_tensor_adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, grad_scale, found_inf, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize, capturable, differentiable)
#     390 else:
#     391     denom = (exp_avg_sq.sqrt() / bias_correction2_sqrt).add_(eps)
# --> 393 param.addcdiv_(exp_avg, denom, value=-step_size)
#
# KeyboardInterrupt:

# %%
def evaluate(model, loss_fn, dataloader):
    model.eval()
    loss = 0
    total_recon_loss = 0
    total_kl_div = 0
    with torch.no_grad():
        for i, batch in enumerate(dataloader):
            batch_data = batch[0]  # get the data from the batch

            # Flatten the data
            batch_data = batch_data.view(batch_data.size(0), -1)

            reconstructed_batch, mu, log_var = model(batch_data)

            # Loss: reconstruction loss + KL divergence
            recon_loss = loss_fn(reconstructed_batch, batch_data)
            kl_divergence = -0.5 * torch.sum(1 + log_var - mu.pow(2) - log_var.exp())
            loss += recon_loss + kl_divergence
            total_recon_loss += recon_loss.item()
            total_kl_div += kl_divergence.item()

    avg_loss = loss / len(dataloader.dataset)
    avg_recon_loss = total_recon_loss / len(dataloader.dataset)
    avg_kl_div = total_kl_div / len(dataloader.dataset)

    return avg_loss, avg_recon_loss, avg_kl_div

# %%
evaluate(model, loss_fn, test_loader)

# %%
def test_model(model, test_loader):
    model.eval()
    with torch.no_grad():
        for i, batch in enumerate(test_loader):
            batch_data = batch[0]  # get the data from the batch
            batch_data = batch_data.view(batch_data.size(0), -1)  # flatten the data
            reconstructed_batch, _, _ = model(batch_data)  # get reconstructed data from the model

            # Convert tensors to numpy arrays for use in pandas
            original_data = batch_data.detach().cpu().numpy()
            reconstructed_data = reconstructed_batch.detach().cpu().numpy()

            # Convert to dataframes
            original_df = pd.DataFrame(original_data)
            reconstructed_df = pd.DataFrame(reconstructed_data)

            if i == 0:  # for the first iteration, create the dataframes
                all_original_df = original_df
                all_reconstructed_df = reconstructed_df
            else:  # for subsequent iterations, append to the existing dataframes
                all_original_df = pd.concat([all_original_df, original_df])
                all_reconstructed_df = pd.concat([all_reconstructed_df, reconstructed_df])
    
    return all_original_df, all_reconstructed_df

# Call the function after training
original_df, reconstructed_df = test_model(model, test_loader)

# 두 데이터 비교

# Flatten the tensors
oriori = compare_data(original_df)
reconrecon = compare_data(reconstructed_df)

# Calculate the Euclidean distance
euclidean_distance = torch.norm(oriori.flatten() - reconrecon.flatten())


print(euclidean_distance)

# %% [markdown]
# # rvae

# %%
class RVAE_Encoder(nn.Module):
    def __init__(self, input_dim, hidden_dim, num_layers, latent_dim):
        super(RVAE_Encoder, self).__init__()
        self.rnn = nn.GRU(input_dim, hidden_dim, num_layers=num_layers, batch_first=True)
        self.fc_mu = nn.Linear(hidden_dim, latent_dim)
        self.fc_var = nn.Linear(hidden_dim, latent_dim)

    def forward(self, x):
        _, hidden = self.rnn(x)
        hidden = hidden[-1]
        mu = self.fc_mu(hidden)
        log_var = self.fc_var(hidden)
        return mu, log_var

class RVAE_Decoder(nn.Module):
    def __init__(self, latent_dim, hidden_dim, num_layers, output_dim, seq_length):
        super(RVAE_Decoder, self).__init__()
        self.fc = nn.Linear(latent_dim, hidden_dim)
        self.rnn = nn.GRU(hidden_dim, output_dim, num_layers=num_layers, batch_first=True)
        self.seq_length = seq_length

    def forward(self, z):
        h = F.relu(self.fc(z))
        h = h.unsqueeze(0).repeat(self.seq_length, 1, 1) 
        out, _ = self.rnn(h)
        return out

class R_VAE(nn.Module):
    def __init__(self, input_dim, hidden_dim, num_layers, latent_dim, output_dim, seq_length):
        super(R_VAE, self).__init__()
        self.encoder = RVAE_Encoder(input_dim, hidden_dim, num_layers, latent_dim)
        self.decoder = RVAE_Decoder(latent_dim, hidden_dim, num_layers, output_dim, seq_length)

    def forward(self, x):
        mu, log_var = self.encoder(x)
        std = torch.exp(0.5 * log_var)
        eps = torch.randn_like(std)
        z = eps.mul(std).add_(mu)
        x = self.decoder(z)
        return x, mu, log_var

# %%
import torch
from torch import nn
from torch import optim
from torch.utils.data import DataLoader, TensorDataset
from torch.utils.data.dataset import random_split

# Hyperparameters
input_dim = 10  # modify this to match your data
hidden_dim = 24  # modify as needed
num_layers = 2  # modify as needed
latent_dim = 2  # modify as needed
output_dim = 10  # modify as needed
lr = 5e-4  # learning rate
n_epochs = 20  # modify as needed
beta = 1


# Lists to store losses for each epoch
avg_losses = []
avg_recon_losses = []
avg_kl_divs = []


# Model, optimizer, and loss function
seq_length = 1000  # Set sequence length to match your target data
model = R_VAE(input_dim, hidden_dim, num_layers, latent_dim, output_dim, seq_length)

# Add seq_length here
optimizer = optim.RAdam(model.parameters(), lr=lr)  # Make sure you're using the correct optimizer
loss_fn = nn.MSELoss()  # And the correct loss function

def train(epoch, model, optimizer, loss_fn, train_loader):
    model.train()
    train_loss = 0
    recon_loss = 0
    kl_div = 0
    for batch_idx, batch in enumerate(train_loader):
        batch_data = batch[0]  # get the data from the batch

        optimizer.zero_grad()

        reconstructed_batch, mu, log_var = model(batch_data)
        reconstructed_batch = reconstructed_batch.permute(1, 0, 2)

#         print("Input size: ", batch_data.size())  # Print input size
#         print("Output size: ", reconstructed_batch.size())  # Print output size

        # Loss: reconstruction loss + KL divergence
        recon_loss = loss_fn(reconstructed_batch, batch_data)
        kl_divergence = -0.5 * torch.sum(1 + log_var - mu.pow(2) - log_var.exp())
        loss = recon_loss + beta*kl_divergence

        loss.backward()
        train_loss += loss.item()
        recon_loss += recon_loss.item()
        kl_div += kl_divergence.item()
        optimizer.step()

    avg_loss = train_loss / len(train_loader.dataset)
    avg_recon_loss = recon_loss / len(train_loader.dataset)
    avg_kl_div = kl_div / len(train_loader.dataset)
    print(f'====> Epoch:{epoch} Average loss:{avg_loss}, Recon Loss:{avg_recon_loss}, KL Div:{avg_kl_div}')
    return avg_loss, avg_recon_loss, avg_kl_div


# Lists to store losses for each epoch
avg_losses = []
avg_recon_losses = []
avg_kl_divs = []

# Training
for epoch in range(1, n_epochs + 1):
    avg_loss, avg_recon_loss, avg_kl_div = train(epoch, model, optimizer, loss_fn, train_loader)
    avg_losses.append(avg_loss)
    avg_recon_losses.append(avg_recon_loss.item())
    avg_kl_divs.append(avg_kl_div)

# Plot the losses
plt.figure(figsize=(7,5))
plt.plot(avg_losses, label='Average Loss')
plt.plot(avg_recon_losses, label='Reconstruction Loss')
plt.plot(avg_kl_divs, label='KL Divergence')
plt.title('Losses')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# ====> Epoch:1 Average loss:0.024795423337391445, Recon Loss:0.0007828651578165591, KL Div:0.013808902646814074
# ====> Epoch:2 Average loss:0.01675598164967128, Recon Loss:0.0007798118749633431, KL Div:0.0058053941173212865
# ====> Epoch:3 Average loss:0.014087305239268712, Recon Loss:0.0007755582919344306, KL Div:0.0031837584120886666
# ====> Epoch:4 Average loss:0.012621038505009242, Recon Loss:0.0007750183576717973, KL Div:0.001760957326207842
# ====> Epoch:5 Average loss:0.011843462467193604, Recon Loss:0.0007722571026533842, KL Div:0.0010228096885340555
# ====> Epoch:6 Average loss:0.011416398354939052, Recon Loss:0.0007701175636611879, KL Div:0.0006308022822652544
# ====> Epoch:7 Average loss:0.011158067328589304, Recon Loss:0.0007672447245568037, KL Div:0.0004015212527343205
# ====> Epoch:8 Average loss:0.010998882225581577, Recon Loss:0.0007657725363969803, KL Div:0.00026690470746585304
# ====> Epoch:9 Average loss:0.010903707197734288, Recon Loss:0.0007647138554602861, KL Div:0.00018887831057821
# ====> Epoch:10 Average loss:0.010845378126416888, Recon Loss:0.0007644707802683115, KL Div:0.00014360286934035166
# ====> Epoch:11 Average loss:0.010808791433061873, Recon Loss:0.000763382762670517, KL Div:0.0001161881855555943
# ====> Epoch:12 Average loss:0.010784840890339443, Recon Loss:0.0007632134947925806, KL Div:9.844054494585309e-05
# ====> Epoch:13 Average loss:0.010768752881458827, Recon Loss:0.0007633111090399325, KL Div:8.61477724143437e-05
# ====> Epoch:14 Average loss:0.010756524971553258, Recon Loss:0.0007627911982126534, KL Div:7.669610636574881e-05
# ====> Epoch:15 Average loss:0.010747694901057652, Recon Loss:0.0007625360740348697, KL Div:6.91853335925511e-05
# ====> Epoch:16 Average loss:0.01074012085369655, Recon Loss:0.0007629473693668842, KL Div:6.275042040007456e-05
# ====> Epoch:17 Average loss:0.010733501468385968, Recon Loss:0.0007623458513990045, KL Div:5.709989581789289e-05
# ====> Epoch:18 Average loss:0.010728003638131279, Recon Loss:0.0007624583668075502, KL Div:5.215455378804888e-05
# ====> Epoch:19 Average loss:0.010723415613174438, Recon Loss:0.0007628162275068462, KL Div:4.7612207276480536e-05
# ====> Epoch:20 Average loss:0.01071909955569676, Recon Loss:0.0007624981226399541, KL Div:4.364830681255886e-05

# %%
# Plot the losses
plt.figure(figsize=(7,5))
plt.plot(avg_losses, label='Average Loss')
plt.plot(avg_recon_losses, label='Reconstruction Loss')  # 수정된 부분
plt.plot(avg_kl_divs, label='KL Divergence')
plt.title('Losses')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# # plotting latent space

# %%
#right

def visualize_latent_space(model, data_loader):
    model.eval()  # Set the model to evaluation mode
    latents = []
    with torch.no_grad():  # No need to track the gradients
        for batch_idx, batch in enumerate(data_loader):
            batch_data = batch[0]  # get the data from the batch
            mu, _ = model.encoder(batch_data)
            latents.append(mu)
    latents = torch.cat(latents)
    print("First 10 points in latent space: ", latents[:10])  # Print the first 10 points
    plt.figure(figsize=(7, 5))
    plt.scatter(latents[:, 0], latents[:, 1], alpha=0.5, s=3)
    plt.show()

# Visualize the latent space
visualize_latent_space(model, train_loader)
# Out:
# First 10 points in latent space:  tensor([[-0.0089, -0.0050],
#         [-0.0100, -0.0032],
#         [-0.0003,  0.0022],
#         [ 0.0030, -0.0014],
#         [ 0.0015, -0.0110],
#         [-0.0004,  0.0037],
#         [-0.0021,  0.0007],
#         [-0.0032,  0.0053],
#         [ 0.0029, -0.0056],
#         [ 0.0049, -0.0071]])

# %%
#front

def visualize_latent_space(model, data_loader):
    model.eval()  # Set the model to evaluation mode
    latents = []
    with torch.no_grad():  # No need to track the gradients
        for batch_idx, batch in enumerate(data_loader):
            batch_data = batch[0]  # get the data from the batch
            mu, _ = model.encoder(batch_data)
            latents.append(mu)
    latents = torch.cat(latents)
    print("First 10 points in latent space: ", latents[:10])  # Print the first 10 points
    plt.figure(figsize=(7, 5))
    plt.scatter(latents[:, 0], latents[:, 1], alpha=0.5, s = 3)
    plt.show()

# Visualize the latent space
visualize_latent_space(model, train_loader)
# Out:
# First 10 points in latent space:  tensor([[-1.3661e-03,  1.8495e-03],
#         [ 4.0335e-03,  4.4838e-04],
#         [ 2.1654e-03, -1.2239e-03],
#         [-2.6562e-04,  3.7198e-03],
#         [-1.6902e-03,  1.6438e-03],
#         [-1.1766e-03, -1.1536e-03],
#         [-7.2140e-05, -2.3508e-03],
#         [ 8.4873e-05, -2.4171e-04],
#         [-8.3761e-04, -1.7419e-03],
#         [ 3.7915e-03,  1.9156e-03]])

# %%
#back

def visualize_latent_space(model, data_loader):
    model.eval()  # Set the model to evaluation mode
    latents = []
    with torch.no_grad():  # No need to track the gradients
        for batch_idx, batch in enumerate(data_loader):
            batch_data = batch[0]  # get the data from the batch
            mu, _ = model.encoder(batch_data)
            latents.append(mu)
    latents = torch.cat(latents)
    print("First 10 points in latent space: ", latents[:10])  # Print the first 10 points
    plt.figure(figsize=(7, 5))
    plt.scatter(latents[:, 0], latents[:, 1], alpha=0.5, s=5)
    plt.show()

# Visualize the latent space
visualize_latent_space(model, train_loader)
# Out:
# First 10 points in latent space:  tensor([[-0.0010, -0.0007],
#         [-0.0050,  0.0008],
#         [-0.0013, -0.0002],
#         [ 0.0027, -0.0016],
#         [-0.0034, -0.0008],
#         [ 0.0030,  0.0030],
#         [-0.0030, -0.0014],
#         [-0.0010, -0.0010],
#         [ 0.0016,  0.0021],
#         [-0.0033, -0.0005]])

# %%
#dance

def visualize_latent_space(model, data_loader):
    model.eval()  # Set the model to evaluation mode
    latents = []
    with torch.no_grad():  # No need to track the gradients
        for batch_idx, batch in enumerate(data_loader):
            batch_data = batch[0]  # get the data from the batch
            mu, _ = model.encoder(batch_data)
            latents.append(mu)
    latents = torch.cat(latents)
    print("First 10 points in latent space: ", latents[:10])  # Print the first 10 points
    plt.figure(figsize=(7, 5))
    plt.scatter(latents[:, 0], latents[:, 1], alpha=0.5, s=3)
    plt.show()

# Visualize the latent space
visualize_latent_space(model, train_loader)
# Out:
# First 10 points in latent space:  tensor([[-0.0012,  0.0002],
#         [ 0.0002, -0.0010],
#         [ 0.0007,  0.0015],
#         [ 0.0013, -0.0018],
#         [ 0.0009,  0.0020],
#         [-0.0015,  0.0003],
#         [-0.0004,  0.0024],
#         [ 0.0001, -0.0003],
#         [ 0.0023, -0.0015],
#         [-0.0008, -0.0002]])

# %% [markdown]
# # UMAP

# %%
#backward

import umap

def visualize_latent_space_umap(model, data_loader):
    model.eval()  # Set the model to evaluation mode
    latents = []
    with torch.no_grad():  # No need to track the gradients
        for batch_idx, batch in enumerate(data_loader):
            batch_data = batch[0]  # get the data from the batch
            mu, _ = model.encoder(batch_data)
            latents.append(mu)
    latents = torch.cat(latents).numpy()  # Convert to numpy array for UMAP
    reducer = umap.UMAP()
    embedding = reducer.fit_transform(latents)
    plt.figure(figsize=(7, 5))
    plt.scatter(embedding[:, 0], embedding[:, 1], alpha=0.5, s=3)
    plt.show()

# Visualize the latent space with UMAP
visualize_latent_space_umap(model, train_loader)

# %%
#front

import umap

def visualize_latent_space_umap(model, data_loader):
    model.eval()  # Set the model to evaluation mode
    latents = []
    with torch.no_grad():  # No need to track the gradients
        for batch_idx, batch in enumerate(data_loader):
            batch_data = batch[0]  # get the data from the batch
            mu, _ = model.encoder(batch_data)
            latents.append(mu)
    latents = torch.cat(latents).numpy()  # Convert to numpy array for UMAP
    reducer = umap.UMAP()
    embedding = reducer.fit_transform(latents)
    plt.figure(figsize=(7, 5))
    plt.scatter(embedding[:, 0], embedding[:, 1], alpha=0.5, s=3)
    plt.show()

# Visualize the latent space with UMAP
visualize_latent_space_umap(model, train_loader)

# %%
#dance

import umap

def visualize_latent_space_umap(model, data_loader):
    model.eval()  # Set the model to evaluation mode
    latents = []
    with torch.no_grad():  # No need to track the gradients
        for batch_idx, batch in enumerate(data_loader):
            batch_data = batch[0]  # get the data from the batch
            mu, _ = model.encoder(batch_data)
            latents.append(mu)
    latents = torch.cat(latents).numpy()  # Convert to numpy array for UMAP
    reducer = umap.UMAP()
    embedding = reducer.fit_transform(latents)
    plt.figure(figsize=(7, 5))
    plt.scatter(embedding[:, 0], embedding[:, 1], alpha=0.5, s=3)
    plt.show()

# Visualize the latent space with UMAP
visualize_latent_space_umap(model, train_loader)

# %% [markdown]
# # HeatMap

# %%
# backward
import seaborn as sns
import numpy as np

def visualize_latent_space_heatmap(model, data_loader):
    model.eval()
    latents = []
    with torch.no_grad():
        for batch_idx, batch in enumerate(data_loader):
            batch_data = batch[0]
            mu, _ = model.encoder(batch_data)
            latents.append(mu)
    latents = torch.cat(latents).numpy()
    n = int(np.sqrt(latents.shape[0]))  # if latents form a square grid
    latents = latents.reshape((n, n))  # reshape to a grid if your data is grid-like
    sns.heatmap(latents)
    plt.show()

visualize_latent_space_heatmap(model, train_loader)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[60], line 19
#      16     sns.heatmap(latents)
#      17     plt.show()
# ---> 19 visualize_latent_space_heatmap(model, train_loader)
#
# Cell In[60], line 15, in visualize_latent_space_heatmap(model, data_loader)
#      13 latents = torch.cat(latents).numpy()
#      14 n = int(np.sqrt(latents.shape[0]))  # if latents form a square grid
# ---> 15 latents = latents.reshape((n, n))  # reshape to a grid if your data is grid-like
#      16 sns.heatmap(latents)
#      17 plt.show()
#
# ValueError: cannot reshape array of size 14000 into shape (83,83)

# %% [markdown]
# # pca

# %%
# backward

from sklearn.decomposition import PCA

def visualize_latent_space_pca(model, data_loader):
    model.eval()  # Set the model to evaluation mode
    latents = []
    with torch.no_grad():  # No need to track the gradients
        for batch_idx, batch in enumerate(data_loader):
            batch_data = batch[0]  # get the data from the batch
            mu, _ = model.encoder(batch_data)
            latents.append(mu)
    latents = torch.cat(latents).numpy()  # Convert to numpy array for PCA
    pca = PCA(n_components=2)
    pca_result = pca.fit_transform(latents)
    plt.figure(figsize=(7, 5))
    plt.scatter(pca_result[:, 0], pca_result[:, 1], alpha=0.5, s = 3)
    plt.show()

# Visualize the latent space with PCA
visualize_latent_space_pca(model, train_loader)

# %%
# dance

from sklearn.decomposition import PCA

def visualize_latent_space_pca(model, data_loader):
    model.eval()  # Set the model to evaluation mode
    latents = []
    with torch.no_grad():  # No need to track the gradients
        for batch_idx, batch in enumerate(data_loader):
            batch_data = batch[0]  # get the data from the batch
            mu, _ = model.encoder(batch_data)
            latents.append(mu)
    latents = torch.cat(latents).numpy()  # Convert to numpy array for PCA
    pca = PCA(n_components=2)
    pca_result = pca.fit_transform(latents)
    plt.figure(figsize=(7, 5))
    plt.scatter(pca_result[:, 0], pca_result[:, 1], alpha=0.5, s = 3)
    plt.show()

# Visualize the latent space with PCA
visualize_latent_space_pca(model, train_loader)

# %%
# front

from sklearn.decomposition import PCA

def visualize_latent_space_pca(model, data_loader):
    model.eval()  # Set the model to evaluation mode
    latents = []
    with torch.no_grad():  # No need to track the gradients
        for batch_idx, batch in enumerate(data_loader):
            batch_data = batch[0]  # get the data from the batch
            mu, _ = model.encoder(batch_data)
            latents.append(mu)
    latents = torch.cat(latents).numpy()  # Convert to numpy array for PCA
    pca = PCA(n_components=2)
    pca_result = pca.fit_transform(latents)
    plt.figure(figsize=(7, 5))
    plt.scatter(pca_result[:, 0], pca_result[:, 1], alpha=0.5, s = 3)
    plt.show()

# Visualize the latent space with PCA
visualize_latent_space_pca(model, train_loader)

# %% [markdown]
# # t-sne

# %%
# backward

from sklearn.manifold import TSNE

def visualize_latent_space_tsne(model, data_loader):
    model.eval()  # Set the model to evaluation mode
    latents = []
    with torch.no_grad():  # No need to track the gradients
        for batch_idx, batch in enumerate(data_loader):
            batch_data = batch[0]  # get the data from the batch
            mu, _ = model.encoder(batch_data)
            latents.append(mu)
    latents = torch.cat(latents).numpy()  # Convert to numpy array for t-SNE
    tsne = TSNE(n_components=2)
    tsne_results = tsne.fit_transform(latents)
    plt.figure(figsize=(7, 5))
    plt.scatter(tsne_results[:, 0], tsne_results[:, 1], alpha=0.5, s =3 )
    plt.show()

# Visualize the latent space with t-SNE
visualize_latent_space_tsne(model, train_loader)

# %%
# dance

# backward

from sklearn.manifold import TSNE

def visualize_latent_space_tsne(model, data_loader):
    model.eval()  # Set the model to evaluation mode
    latents = []
    with torch.no_grad():  # No need to track the gradients
        for batch_idx, batch in enumerate(data_loader):
            batch_data = batch[0]  # get the data from the batch
            mu, _ = model.encoder(batch_data)
            latents.append(mu)
    latents = torch.cat(latents).numpy()  # Convert to numpy array for t-SNE
    tsne = TSNE(n_components=2)
    tsne_results = tsne.fit_transform(latents)
    plt.figure(figsize=(7, 5))
    plt.scatter(tsne_results[:, 0], tsne_results[:, 1], alpha=0.5, s =3 )
    plt.show()

# Visualize the latent space with t-SNE
visualize_latent_space_tsne(model, train_loader)

# %%
# front

from sklearn.manifold import TSNE

def visualize_latent_space_tsne(model, data_loader):
    model.eval()  # Set the model to evaluation mode
    latents = []
    with torch.no_grad():  # No need to track the gradients
        for batch_idx, batch in enumerate(data_loader):
            batch_data = batch[0]  # get the data from the batch
            mu, _ = model.encoder(batch_data)
            latents.append(mu)
    latents = torch.cat(latents).numpy()  # Convert to numpy array for t-SNE
    tsne = TSNE(n_components=2)
    tsne_results = tsne.fit_transform(latents)
    plt.figure(figsize=(7, 5))
    plt.scatter(tsne_results[:, 0], tsne_results[:, 1], alpha=0.5, s =3 )
    plt.show()

# Visualize the latent space with t-SNE
visualize_latent_space_tsne(model, train_loader)

# %% [markdown]
# # see the output

# %%
def test_model(model, test_loader):
    model.eval()
    with torch.no_grad():
        for i, batch in enumerate(test_loader):
            batch_data = batch[0]  # get the data from the batch
            batch_data = batch_data.view(batch_data.size(0), -1)  # flatten the data
            reconstructed_batch, _, _ = model(batch_data)  # get reconstructed data from the model

            # Convert tensors to numpy arrays for use in pandas
            original_data = batch_data.detach().cpu().numpy()
            reconstructed_data = reconstructed_batch.detach().cpu().numpy()

            # Convert to dataframes
            original_df = pd.DataFrame(original_data)
            reconstructed_df = pd.DataFrame(reconstructed_data)

            if i == 0:  # for the first iteration, create the dataframes
                all_original_df = original_df
                all_reconstructed_df = reconstructed_df
            else:  # for subsequent iterations, append to the existing dataframes
                all_original_df = pd.concat([all_original_df, original_df])
                all_reconstructed_df = pd.concat([all_reconstructed_df, reconstructed_df])
    
    return all_original_df, all_reconstructed_df

# Call the function after training
original_df, reconstructed_df = test_model(model, test_loader)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[73], line 27
#      24     return all_original_df, all_reconstructed_df
#      26 # Call the function after training
# ---> 27 original_df, reconstructed_df = test_model(model, test_loader)
#
# Cell In[73], line 7, in test_model(model, test_loader)
#       5 batch_data = batch[0]  # get the data from the batch
#       6 batch_data = batch_data.view(batch_data.size(0), -1)  # flatten the data
# ----> 7 reconstructed_batch, _, _ = model(batch_data)  # get reconstructed data from the model
#       9 # Convert tensors to numpy arrays for use in pandas
#      10 original_data = batch_data.detach().cpu().numpy()
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/firstenv/lib/python3.11/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# Cell In[45], line 35, in R_VAE.forward(self, x)
#      34 def forward(self, x):
# ---> 35     mu, log_var = self.encoder(x)
#      36     std = torch.exp(0.5 * log_var)
#      37     eps = torch.randn_like(std)
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/firstenv/lib/python3.11/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# Cell In[45], line 9, in RVAE_Encoder.forward(self, x)
#       8 def forward(self, x):
# ----> 9     _, hidden = self.rnn(x)
#      10     hidden = hidden[-1]
#      11     mu = self.fc_mu(hidden)
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/firstenv/lib/python3.11/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/firstenv/lib/python3.11/site-packages/torch/nn/modules/rnn.py:996, in GRU.forward(self, input, hx)
#     991 else:
#     992     # Each batch of the hidden state should match the input sequence that
#     993     # the user believes he/she is passing in.
#     994     hx = self.permute_hidden(hx, sorted_indices)
# --> 996 self.check_forward_args(input, hx, batch_sizes)
#     997 if batch_sizes is None:
#     998     result = _VF.gru(input, hx, self._flat_weights, self.bias, self.num_layers,
#     999                      self.dropout, self.training, self.bidirectional, self.batch_first)
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/firstenv/lib/python3.11/site-packages/torch/nn/modules/rnn.py:253, in RNNBase.check_forward_args(self, input, hidden, batch_sizes)
#     252 def check_forward_args(self, input: Tensor, hidden: Tensor, batch_sizes: Optional[Tensor]):
# --> 253     self.check_input(input, batch_sizes)
#     254     expected_hidden_size = self.get_expected_hidden_size(input, batch_sizes)
#     256     self.check_hidden_size(hidden, expected_hidden_size)
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/firstenv/lib/python3.11/site-packages/torch/nn/modules/rnn.py:218, in RNNBase.check_input(self, input, batch_sizes)
#     214     raise RuntimeError(
#     215         'input must have {} dimensions, got {}'.format(
#     216             expected_input_dim, input.dim()))
#     217 if self.input_size != input.size(-1):
# --> 218     raise RuntimeError(
#     219         'input.size(-1) must be equal to input_size. Expected {}, got {}'.format(
#     220             self.input_size, input.size(-1)))
#
# RuntimeError: input.size(-1) must be equal to input_size. Expected 2, got 2000

# %%
original_df

# %%
reconstructed_df

# %%
def compare_data(data):

    # Get the first row from the dataframe
    first_row = data.iloc[0]

    # Reshape it to (1000, 10)
    reshaped_array = np.reshape(first_row.values, (1000, 2))

    # Convert it back to a dataframe
    reshaped_df = pd.DataFrame(reshaped_array)
    recon_combined_tensor = torch.tensor(reshaped_df.values)
    return recon_combined_tensor

# %%
# Get the first row from the dataframe
first_row = reconstructed_df.iloc[0]

# Reshape it to (1000, 10)
reshaped_array = np.reshape(first_row.values, (1000, 2))

# Convert it back to a dataframe
reshaped_df = pd.DataFrame(reshaped_array)
recon_combined_tensor = torch.tensor(reshaped_df.values)

# %%
replay(reshaped_df)

# %%
# Get the first row from the dataframe
first_row = original_df.iloc[0]

# Reshape it to (1000, 10)
reshaped_array = np.reshape(first_row.values, (1000, 2))

# Convert it back to a dataframe
reshaped_df = pd.DataFrame(reshaped_array)
ori_combined_tensor = torch.tensor(reshaped_df.values)

# %%
replay(reshaped_df)

# %%
recon_combined_tensor-ori_combined_tensor

# %%
# Flatten the tensors
flattened_ori = ori_combined_tensor.flatten()
flattened_recon = recon_combined_tensor.flatten()

# Calculate the Euclidean distance
euclidean_distance = torch.norm(flattened_ori - flattened_recon)


print(euclidean_distance)

# %%
# 두 데이터 비교

# Flatten the tensors
oriori = compare_data(original_df)
reconrecon = compare_data(reconstructed_df)

# Calculate the Euclidean distance
euclidean_distance = torch.norm(oriori.flatten() - reconrecon.flatten())


print(euclidean_distance)

# %% [markdown]
# # render with action

# %%
import torch

# Convert combined_arr to PyTorch Tensor
# combined_tensor = torch.from_numpy(combined_arr)

# Print the shape of combined_tensor
print(combined_tensor.shape)

import matplotlib.pyplot as plt
from IPython import display
import gym


def replay(combined_data):

    action_sp = combined_data.iloc[:]
    env = gym.make('Swimmer-v3', render_mode = 'human')

    # Iterate through the rows
    for i in range(len(action_sp)):
        # Get the i-th row
        action = action_sp.iloc[i]
        print(action)

        # If this is the first iteration, set the environment state to the given observation
        # Note: This assumes that the observation you've stored is the entire state that can be set with `env.reset()`
        # If this is not the case, you cannot simply set the environment state to the observation
        if i == 0:
            env.reset()  # We ignore the initial observation returned by `reset`

        # Apply the action
        next_observation, reward, done, trunc, info = env.step(action)
        # Render the environment
        env.render()
        # If you want to slow down each step for viewing, you can use time.sleep
        # time.sleep(0.01)

    # Close the environment
    env.close()
# Out:
# torch.Size([10000, 1000, 2])

# %%
action_sp
